# %% [markdown]
# # FIFA  PLAYER  VALUE  PREDICTIONS

# %% [markdown]
# The purpose of this project is to take a dataset of European FIFA players and develop a multiple linear regression model that can predict the value of new players.
#
# ***Target Variable:*** Player Value
#
#
# ## The Business Case
#
# The Flatiron FIFA team has struggled to acuire and retain top talent, which has resulted in game losses, a notcable decrease in brand equity, and financial losses in merchandising and ticket sales.  TEAM NAME has approached EA Sports, the video game developer, to help them revamp their recruiting and contracting because EA has the data and technology to simulate the entire FIFA organization.  TEAM NAME wants to identify top talent sooner, when players are young, determine their market value, and execute a long term contract that is financially advantageous.  In addition to top players who can win championships, they want players with an engaging personality who can win a die-hard fan base.  Their key questions include:
#   *   What are the key characteristics of a top player, which can be identified at the beginning of a career?
#   *   Is there any truth to the old belief that left footed players are more valuable than right footed?
#   *   What is the average value of players based on their age group, especially the 16-19 age range?
#   *   What type of linear regression machine learning model can accurately identify top talent and determine their market value?
#
#
# ## The Data
#
# The dataset is comprised of over 17,000 players from the EA Sports video game.  The dataset came with approximately 90 features, some of which are identifiers for the player including jersey number and date of birth while other features dig into their performance as a player in a wide variety of skills.  The dataset was created by RAGHAV GURUNG and you can access it at <a href="https://data.world/raghav333/fifa-players" target="_blank">***data.world***</a>
#
# ## The Regression Model
#
# We will use an OLS (Ordinary Least Squares) model, which is designed to minimize the amount of error (distance between the line and the data points when graphed) to increase it's predictive power.  We split the dataset into a training set (a random sample of 80% of the data) to fit the model and then used a test set of the remaining data to evaluate the model's accuracy.
#
# ## The Process<span id="0"></span>
#
#
# * #### Import & Cleaning
#     *   [**Import:**](#1)  Imported the .CSV file as a Pandas DataFrame.
#     *   [***Data Types:***](#2)  Checked for data types and removed any unnecessary features that contained string data.
#     *   [***Null Values:***](#3)  Identified Null values and either removed them or transformed them into an appropriate value.
#     *   [***Categorical Data:***](#4)  Identified categorical data and either dropped it or transformed it into numerical dummy variables.
#     *   [***Outliers:***](#5)  Removed the top and bottom 2.5% of the dataset (the extreme outliers), which created unnecessary variance.
#
#
# * #### Check Correlation & Linearity
#     *   [***Target Correlation:***](#6) Checked for correlations between the target variable and the features to get an initial sense of which features have an influence on the target variable.  We also check to see if data plots are linear or curvilinear.
#     *   [***Feature Correlation:***](#7) Checked for correlations between features which would cause multicollinearity.  If two features are highly corrletated, then you really only need one of the two.  Having both could negatively impact the accuracy of your other coefficients.
#     *   [***Record Corrlations:***](#8) Make a note of any features you want to keep an eye on and possibly drop when improving your model.  We also begin to answer the question of which characteristics are indicative of a high value player.
#
#
# * #### Hypothesis Testing
#     *  Before we dig into building models, we start by addressing the key questions we were asked to gain insights into how to identify new talent.
#     *   [***Left vs. Right Foot:***](#9) Make a note of any features you want to keep an eye on and possibly drop when improving your model.
#     *   [***New-Comer vs. Veteran:***](#10) Make a note of any features you want to keep an eye on and possibly drop when improving your model.
#
#
# * #### Feature Engineering
#     *  [***Aggregate Features:***](#11)  We create 6 new features that aggregrate the 24 player characteristics into 6 categories.  We add the values in each category and divide by the number of characterisitcs in each category to get the average rating.  For example, the attacking category score is the sum of crossing, finishing, heading_accuracy, short_passing, and volleys divided by 5.
#
#
# * #### Standardization
#     *   Stardization is similar to normalization in that you are transforming the data into common units. There may be a great deal of difference between the units of features.  Some data points, like year, have very high numberical units compared to number of bathrooms, which is very low.  You don't want some coefficients to be weighted higher simply because they are using a different unit of measurement.  To solve this, you can onvert each data point into its z-score and then compare the data's z-scores.
#     *   [***Standard Scaler:***](#12)  We scaled the data using the Standard Scaler and added these scaled columns to the end of our dataFrame, so we could include them in model development.
#
#
# * #### Split the Data
#     *  [***Train/ Test Split:***](#13)  Before you train the model, you should split the data into a training set and a test set.  This will allow us to build a model and then test its predictive strength.  We also conducted a 5-fold cross validation test so we could validate our model.
#
#
# * #### Build Linear Regression Models
#     *  [***Linear Regressions:***](#14)  Build several combinations of linear models using the training set.
#     *  Get the summary statistics and look for ways to improve. Specifically look at the RMSE, R-Squared and Adj. R-Squared as well as the p-values for each coefficient to determine which are really useful.
#     *  Record the summary statistics for each model you generate as well as the specific characteristics of the model that produced those results.
#
#
# * #### Regularization
#     *   The purpose of regularization is to avoid over and underfitting a model to the training set and to find the right balance between complexity and generalizability.  If the model is too complex, meaning it can't generalize to new data, then you need to reduce that complexity.
#     *   There are two methods for regularization: Ridge & Lasso.  Both add an argument at the end of the regression equation that sums all of the coefficients, squares that sum and then uses this number to penalize any coefficients that are too extreme.
#     *   [***Ridge Regression:***](#15)Ridge regularization minimizes the impact of extreme coefficients.
#     *   [***Lasso Regression:***](#16)Lasso goes a step further to determines which features are strongest and then zeros out the weakest features.  This is useful when you have a long list of features and you need to determine which are best.
#
#
# * #### Polynomial Regression
#     *   We attempted a polynomial regression, but kept crashing our kernel in the process.  We were unable to see if this model would have improved our model's predictive strength.
#
#
# * #### Checking for Multivariate Normality & Homoscedasticity
#     *   [***Normality & Homoscedasticity:***](#17)  One of the basic assumptions of linear regression is that the residuals are normally distributed.  If the data isn't normally distriuted, then a linear regression model probably won't give you the results you're looking for.  It's good to know if your model is breaking this assumption and to what degree.
#     *   We want our distribution of errors to be homoscedastic, meaning the error terms are similar across the values of the independent variables.  There should be no identifiable pattern in the plot.
#
#
# ## Results
#
# Below is a table of the various models we developed and their performance.  The key metrics we used to evaluate the models are:
#    *   RMSE (Root Mean Squared Error) This is the sum of the residual distance between expected y values and actual y values, which is squared to remove negative values, divided by the number of y values, and then brought back down to scale with a squareroot.  The lower the number the better.
#    *   R-Squared is essnetially the amount of error which is explained by the model and is equal to the RSS/TSS.  A higher R-Squared means the more error the model can account for.
#    *   Adjusted R-Squared is always lower than R-Squared because it penalizes the R-Squared if there is excessive use of independent variables, which usually increases R-Squared.  This is a more reliable or conservative metric.
#    *   We see these metrics for both the training and test set, which indicates how generalizable the model is to new datapoints or sets.  The more consistent these metrics, the more effective it is at consistently predicting values.      *   5-Fold Cross Validation takes the training set and divides it into 5 equal sets.  The R-Squared is calculated for each, summed and then divided by 5 to get the average R-Squared.  Again, another way of checking for generalizability and consistency.
#
# Despite all of the different types of models we developed, it appears the very first model, a Multiple-Linear Regression containing all features without standard scaling, performed the best.

# %%
evaluate
# Out:
#                Model                                          Details  \
# 0              MLR_1                      all features, not processed
# 1              MLR_2                       all features, preprocessed
# 2              MLR_3                basic & individual, not processed
# 3              MLR_4                basic & categories, not processed
# 4              MLR_5    basic, individual & categories, not processed
# 5              MLR_6                 basic & individual, preprocessed
# 6              MLR_7                 basic & categories, preprocessed
# 7              MLR_8     basic, individual & categories, preprocessed
# 8   Ridge Regression             alpha=1, all features, not processed
# 9   Ridge Regression           alpha=100, all features, not processed
# 10  Ridge Regression          alpha=1000, all features, not processed
# 11  Ridge Regression     alpha=1, basic and individual, not processed
# 12  Ridge Regression   alpha=100, basic and individual, not processed
# 13  Ridge Regression  alpha=1000, basic and individual, not processed
# 14  Ridge Regression       alpha=1, basic & categories, not processed
# 15  Ridge Regression     alpha=100, basic & categories, not processed
# 16  Ridge Regression    alpha=1000, basic & categories, not processed
# 17  Lasso Regression                            alpha=1, all features
# 18  Lasso Regression                          alpha=100, all features
# 19  Lasso Regression                         alpha=1000, all features
#
#     Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                   1562209.347000              0.662000
# 1                   1562208.121000              0.662000
# 2                   1573193.418000              0.657000
# 3                   1575590.586000              0.658000
# 4                   1580000.765000              0.654000
# 5                   1580000.765000              0.654000
# 6                   1575590.586000              0.658000
# 7                   1567862.487000              0.660000
# 8                   1562208.548000              0.662000
# 9                   1562207.421000              0.662000
# 10                  1562294.896000              0.662000
# 11                  1573193.421000              0.657000
# 12                  1573194.848000              0.657000
# 13                  1573272.934000              0.657000
# 14                  1575590.667000              0.658000
# 15                  1575599.611000              0.658000
# 16                  1575742.902000              0.658000
# 17                  1562208.585000              0.662000
# 18                  1562209.716000              0.662000
# 19                  1562239.375000              0.662000
#
#     Adjusted R-squared (training)  R-squared (test)  \
# 0                        0.661000          0.660000
# 1                        0.661000          0.660000
# 2                        0.657000          0.656000
# 3                        0.657000          0.654000
# 4                        0.654000          0.653000
# 5                        0.654000          0.653000
# 6                        0.657000          0.654000
# 7                        0.659000          0.658000
# 8                        0.661000          0.660000
# 9                        0.661000          0.660000
# 10                       0.661000          0.660000
# 11                       0.657000          0.656000
# 12                       0.657000          0.656000
# 13                       0.657000          0.655000
# 14                       0.657000          0.654000
# 15                       0.657000          0.654000
# 16                       0.657000          0.654000
# 17                       0.661000          0.660000
# 18                       0.661000          0.660000
# 19                       0.661000          0.660000
#
#     Adjusted R-squared (test)  5-Fold Cross Validation
# 0                    0.656000                 0.659000
# 1                    0.656000                 0.659000
# 2                    0.654000                 0.656000
# 3                    0.653000                 0.656000
# 4                    0.652000                 0.653000
# 5                    0.652000                 0.653000
# 6                    0.653000                 0.656000
# 7                    0.656000                 0.658000
# 8                    0.656000                 0.659000
# 9                    0.656000                 0.659000
# 10                   0.656000                 0.659000
# 11                   0.654000                 0.656000
# 12                   0.654000                 0.656000
# 13                   0.654000                 0.655000
# 14                   0.653000                 0.656000
# 15                   0.653000                 0.656000
# 16                   0.653000                 0.656000
# 17                   0.656000                 0.659000
# 18                   0.656000                 0.659000
# 19                   0.656000                 0.659000

# %% [markdown]
# # Import Packages
# #### [Return Contents](#0)
# <hr/>

# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
sns.set(style="white")
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import warnings
import statsmodels.api as sm
warnings.filterwarnings('ignore')

# %%
evaluate = pd.DataFrame({'Model': [],
                           'Details':[],
                           'Root Mean Squared Error (RMSE)':[],
                           'R-squared (training)':[],
                           'Adjusted R-squared (training)':[],
                           'R-squared (test)':[],
                           'Adjusted R-squared (test)':[],
                           '5-Fold Cross Validation':[]})

# %% [markdown]
# # <span id="1"></span> Import .CSV
# #### [Return Contents](#0)
# <hr/>

# %%
df = pd.read_csv('fifa_cleaned.csv', index_col=0)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                 name                       full_name  birth_date  age  \
# id
# 158023      L. Messi  Lionel Andrés Messi Cuccittini  1987-06-24   31
# 190460    C. Eriksen    Christian  Dannemann Eriksen  1992-02-14   27
# 195864      P. Pogba                      Paul Pogba  1993-03-15   25
# 198219    L. Insigne                 Lorenzo Insigne  1991-06-04   27
# 201024  K. Koulibaly               Kalidou Koulibaly  1991-06-20   27
#
#         height_cm  weight_kgs  positions nationality  overall_rating  \
# id
# 158023 170.180000   72.100000   CF,RW,ST   Argentina              94
# 190460 154.940000   76.200000  CAM,RM,CM     Denmark              88
# 195864 190.500000   83.900000     CM,CAM      France              88
# 198219 162.560000   59.000000      LW,ST       Italy              88
# 201024 187.960000   88.900000         CB     Senegal              88
#
#         potential       value_euro     wage_euro preferred_foot  \
# id
# 158023         94 110500000.000000 565000.000000           Left
# 190460         89  69500000.000000 205000.000000          Right
# 195864         91  73000000.000000 255000.000000          Right
# 198219         88  62000000.000000 165000.000000          Right
# 201024         91  60000000.000000 135000.000000          Right
#
#         international_reputation(1-5)  weak_foot(1-5)  skill_moves(1-5)  \
# id
# 158023                              5               4                 4
# 190460                              3               5                 4
# 195864                              4               4                 5
# 198219                              3               4                 4
# 201024                              3               3                 2
#
#            work_rate body_type  release_clause_euro          club_team  \
# id
# 158023   Medium/ Low     Messi     226500000.000000       FC Barcelona
# 190460  High/ Medium      Lean     133800000.000000  Tottenham Hotspur
# 195864  High/ Medium    Normal     144200000.000000  Manchester United
# 198219  High/ Medium    Normal     105400000.000000             Napoli
# 201024    High/ High    Normal     106500000.000000             Napoli
#
#         club_rating club_position  club_jersey_number club_join_date  \
# id
# 158023    86.000000            RW           10.000000     2004-07-01
# 190460    83.000000           LCM           23.000000     2013-08-30
# 195864    82.000000           LCM            6.000000     2016-08-09
# 198219    82.000000            LS           24.000000     2010-07-01
# 201024    82.000000           LCB           26.000000     2014-07-01
#
#        contract_end_year national_team  national_rating  \
# id
# 158023              2021     Argentina        82.000000
# 190460              2020       Denmark        78.000000
# 195864              2021        France        84.000000
# 198219              2022         Italy        83.000000
# 201024              2021           NaN              nan
#
#        national_team_position  national_jersey_number  crossing  finishing  \
# id
# 158023                     RF               10.000000        86         95
# 190460                    CAM               10.000000        88         81
# 195864                    RDM                6.000000        80         75
# 198219                     LW               10.000000        86         77
# 201024                    NaN                     nan        30         22
#
#         heading_accuracy  short_passing  volleys  dribbling  curve  \
# id
# 158023                70             92       86         97     93
# 190460                52             91       80         84     86
# 195864                75             86       85         87     85
# 198219                56             85       74         90     87
# 201024                83             68       14         69     28
#
#         freekick_accuracy  long_passing  ball_control  acceleration  \
# id
# 158023                 94            89            96            91
# 190460                 87            89            91            76
# 195864                 82            90            90            71
# 198219                 77            78            93            94
# 201024                 28            60            63            70
#
#         sprint_speed  agility  reactions  balance  shot_power  jumping  \
# id
# 158023            86       93         95       95          85       68
# 190460            73       80         88       81          84       50
# 195864            79       76         82       66          90       83
# 198219            86       94         83       93          75       53
# 201024            75       50         82       40          55       81
#
#         stamina  strength  long_shots  aggression  interceptions  positioning  \
# id
# 158023       72        66          94          48             22           94
# 190460       92        58          89          46             56           84
# 195864       88        87          82          78             64           82
# 198219       75        44          84          34             26           83
# 201024       75        94          15          87             88           24
#
#         vision  penalties  composure  marking  standing_tackle  \
# id
# 158023      94         75         96       33               28
# 190460      91         67         88       59               57
# 195864      88         82         87       63               67
# 198219      87         61         83       51               24
# 201024      49         33         80       91               88
#
#         sliding_tackle  GK_diving  GK_handling  GK_kicking  GK_positioning  \
# id
# 158023              26          6           11          15              14
# 190460              22          9           14           7               7
# 195864              67          5            6           2               4
# 198219              22          8            4          14               9
# 201024              87          7           11           7              13
#
#         GK_reflexes                                               tags  \
# id
# 158023            8  #Dribbler,#Distance Shooter,#Crosser,#FK Speci...
# 190460            6  #Playmaker  ,#Crosser,#FK Specialist,#Complete...
# 195864            3  #Dribbler,#Playmaker  ,#Strength,#Complete Mid...
# 198219           10             #Speedster,#Dribbler,#Crosser,#Acrobat
# 201024            5  #Tackling ,#Tactician ,#Strength,#Complete Def...
#
#                                                    traits    LS    ST    RS  \
# id
# 158023  Finesse Shot,Long Shot Taker (CPU AI Only),Spe...  89+2  89+2  89+2
# 190460  Flair,Long Shot Taker (CPU AI Only),Playmaker ...  79+3  79+3  79+3
# 195864  Flair,Long Passer (CPU AI Only),Long Shot Take...  81+3  81+3  81+3
# 198219  Finesse Shot,Long Shot Taker (CPU AI Only),Spe...  78+3  78+3  78+3
# 201024                                       Power Header  53+3  53+3  53+3
#
#           LW    LF    CF    RF    RW   LAM   CAM   RAM    LM   LCM    CM  \
# id
# 158023  93+2  93+2  93+2  93+2  93+2  93+2  93+2  93+2  91+2  85+2  85+2
# 190460  85+3  84+3  84+3  84+3  85+3  86+3  86+3  86+3  86+3  85+3  85+3
# 195864  82+3  83+3  83+3  83+3  82+3  84+3  84+3  84+3  83+3  84+3  84+3
# 198219  86+3  85+3  85+3  85+3  86+3  86+3  86+3  86+3  86+3  78+3  78+3
# 201024  53+3  54+3  54+3  54+3  53+3  55+3  55+3  55+3  57+3  61+3  61+3
#
#          RCM    RM   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB    RB
# id
# 158023  85+2  91+2  64+2  61+2  61+2  61+2  64+2  59+2  48+2  48+2  48+2  59+2
# 190460  85+3  86+3  71+3  71+3  71+3  71+3  71+3  66+3  57+3  57+3  57+3  66+3
# 195864  84+3  83+3  76+3  77+3  77+3  77+3  76+3  74+3  72+3  72+3  72+3  74+3
# 198219  78+3  86+3  63+3  58+3  58+3  58+3  63+3  58+3  44+3  44+3  44+3  58+3
# 201024  61+3  57+3  73+3  77+3  77+3  77+3  73+3  76+3  85+3  85+3  85+3  76+3

# %%
df.shape
# Out:
# (17954, 91)

# %%
df.dtypes
# Out:
# name           object
# full_name      object
# birth_date     object
# age             int64
# height_cm     float64
#                ...
# LB             object
# LCB            object
# CB             object
# RCB            object
# RB             object
# Length: 91, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'full_name', 'birth_date', 'age', 'height_cm', 'weight_kgs',
#        'positions', 'nationality', 'overall_rating', 'potential', 'value_euro',
#        'wage_euro', 'preferred_foot', 'international_reputation(1-5)',
#        'weak_foot(1-5)', 'skill_moves(1-5)', 'work_rate', 'body_type',
#        'release_clause_euro', 'club_team', 'club_rating', 'club_position',
#        'club_jersey_number', 'club_join_date', 'contract_end_year',
#        'national_team', 'national_rating', 'national_team_position',
#        'national_jersey_number', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes', 'tags', 'traits', 'LS', 'ST', 'RS',
#        'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB'],
#       dtype='object')

# %% [markdown]
# # <span id="2"></span> Data Types and Dropping Unecessary Columns
# #### [Return Contents](#0)

# %% [markdown]
# We dropped many of the original 81 columns either because the data wasn't useful or because there were other variables that essentially provided the same data from a different perspective.  For example, weak_foot is unnecessary when you know preferred_foot.  Also some variables wouldn't help us determine a potential top player early in their career.  New-comers aren't likely to have an international reputation.

# %%
df = df.drop(['full_name', 'birth_date', 'positions', 'international_reputation(1-5)', 'weak_foot(1-5)', 'skill_moves(1-5)', 'work_rate', 'body_type', 'club_jersey_number', 'club_join_date', 'contract_end_year', 'national_jersey_number', 'tags', 'traits', 'LS', 'ST', 'RS',
       'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
       'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
       'RCB', 'RB'], axis=1)

# %%
df
# Out:
#                   name  age  height_cm  weight_kgs   nationality  \
# id
# 158023        L. Messi   31 170.180000   72.100000     Argentina
# 190460      C. Eriksen   27 154.940000   76.200000       Denmark
# 195864        P. Pogba   25 190.500000   83.900000        France
# 198219      L. Insigne   27 162.560000   59.000000         Italy
# 201024    K. Koulibaly   27 187.960000   88.900000       Senegal
# ...                ...  ...        ...         ...           ...
# 204322     R. McKenzie   25 175.260000   74.800000      Scotland
# 239762       M. Sipľak   23 182.880000   79.800000      Slovakia
# 235155      J. Bekkema   22 185.420000   89.800000   Netherlands
# 244883      A. Al Yami   21 175.260000   64.900000  Saudi Arabia
# 247187  Júnior Brumado   19 190.500000   79.800000        Brazil
#
#         overall_rating  potential       value_euro     wage_euro  \
# id
# 158023              94         94 110500000.000000 565000.000000
# 190460              88         89  69500000.000000 205000.000000
# 195864              88         91  73000000.000000 255000.000000
# 198219              88         88  62000000.000000 165000.000000
# 201024              88         91  60000000.000000 135000.000000
# ...                ...        ...              ...           ...
# 204322              67         70    975000.000000   3000.000000
# 239762              59         67    190000.000000   1000.000000
# 235155              59         67    170000.000000   1000.000000
# 244883              59         71    280000.000000   4000.000000
# 247187              59         75    325000.000000   2000.000000
#
#        preferred_foot  release_clause_euro          club_team  club_rating  \
# id
# 158023           Left     226500000.000000       FC Barcelona    86.000000
# 190460          Right     133800000.000000  Tottenham Hotspur    83.000000
# 195864          Right     144200000.000000  Manchester United    82.000000
# 198219          Right     105400000.000000             Napoli    82.000000
# 201024          Right     106500000.000000             Napoli    82.000000
# ...               ...                  ...                ...          ...
# 204322          Right       1800000.000000         Kilmarnock    67.000000
# 239762           Left        295000.000000           Cracovia    65.000000
# 235155          Right        289000.000000      SC Heerenveen    69.000000
# 244883          Right        532000.000000           Al Hilal    74.000000
# 247187          Right        626000.000000     FC Midtjylland    71.000000
#
#        club_position national_team  national_rating national_team_position  \
# id
# 158023            RW     Argentina        82.000000                     RF
# 190460           LCM       Denmark        78.000000                    CAM
# 195864           LCM        France        84.000000                    RDM
# 198219            LS         Italy        83.000000                     LW
# 201024           LCB           NaN              nan                    NaN
# ...              ...           ...              ...                    ...
# 204322           SUB           NaN              nan                    NaN
# 239762            LB           NaN              nan                    NaN
# 235155           RES           NaN              nan                    NaN
# 244883           RES           NaN              nan                    NaN
# 247187           RES           NaN              nan                    NaN
#
#         crossing  finishing  heading_accuracy  short_passing  volleys  \
# id
# 158023        86         95                70             92       86
# 190460        88         81                52             91       80
# 195864        80         75                75             86       85
# 198219        86         77                56             85       74
# 201024        30         22                83             68       14
# ...          ...        ...               ...            ...      ...
# 204322        57         61                60             66       37
# 239762        50         19                53             55       31
# 235155        11          9                13             26        9
# 244883        42         60                55             49       49
# 247187        32         58                58             47       39
#
#         dribbling  curve  freekick_accuracy  long_passing  ball_control  \
# id
# 158023         97     93                 94            89            96
# 190460         84     86                 87            89            91
# 195864         87     85                 82            90            90
# 198219         90     87                 77            78            93
# 201024         69     28                 28            60            63
# ...           ...    ...                ...           ...           ...
# 204322         64     53                 47            61            66
# 239762         52     26                 28            43            53
# 235155         12     13                 12            24            18
# 244883         57     47                 39            37            56
# 247187         58     35                 25            37            56
#
#         acceleration  sprint_speed  agility  reactions  balance  shot_power  \
# id
# 158023            91            86       93         95       95          85
# 190460            76            73       80         88       81          84
# 195864            71            79       76         82       66          90
# 198219            94            86       94         83       93          75
# 201024            70            75       50         82       40          55
# ...              ...           ...      ...        ...      ...         ...
# 204322            83            86       93         63       82          51
# 239762            70            64       54         50       53          27
# 235155            27            22       29         48       38          17
# 244883            84            86       65         53       73          56
# 247187            67            72       71         54       59          61
#
#         jumping  stamina  strength  long_shots  aggression  interceptions  \
# id
# 158023       68       72        66          94          48             22
# 190460       50       92        58          89          46             56
# 195864       83       88        87          82          78             64
# 198219       53       75        44          84          34             26
# 201024       81       75        94          15          87             88
# ...         ...      ...       ...         ...         ...            ...
# 204322       77       75        64          54          69             41
# 239762       74       66        70          22          62             55
# 235155       43       25        63           9          27             10
# 244883       58       58        49          58          38             15
# 247187       60       57        67          53          67             20
#
#         positioning  vision  penalties  composure  marking  standing_tackle  \
# id
# 158023           94      94         75         96       33               28
# 190460           84      91         67         88       59               57
# 195864           82      88         82         87       63               67
# 198219           83      87         61         83       51               24
# 201024           24      49         33         80       91               88
# ...             ...     ...        ...        ...      ...              ...
# 204322           60      64         63         56       40               20
# 239762           42      39         32         52       53               64
# 235155            5      25         16         47        9               12
# 244883           54      52         50         53       16               18
# 247187           53      49         52         45       23               31
#
#         sliding_tackle  GK_diving  GK_handling  GK_kicking  GK_positioning  \
# id
# 158023              26          6           11          15              14
# 190460              22          9           14           7               7
# 195864              67          5            6           2               4
# 198219              22          8            4          14               9
# 201024              87          7           11           7              13
# ...                ...        ...          ...         ...             ...
# 204322              18         15           11          15              12
# 239762              60         15            7           7              15
# 235155              13         63           57          50              58
# 244883              17         15           14          12               6
# 247187              21          9           14          12              13
#
#         GK_reflexes
# id
# 158023            8
# 190460            6
# 195864            3
# 198219           10
# 201024            5
# ...             ...
# 204322            7
# 239762            8
# 235155           63
# 244883            9
# 247187           14
#
# [17954 rows x 51 columns]

# %%
df.shape
# Out:
# (17954, 51)

# %% [markdown]
# # <span id="3"></span> Identify Null Values
# #### [Return Contents](#0)

# %% [markdown]
# We identified several columns with null values.  We removed any observations that didn't contain the player's value and/or wage.  We also update the null values in the release clause column to zeros.

# %%
df.isnull().sum()
# Out:
# name                          0
# age                           0
# height_cm                     0
# weight_kgs                    0
# nationality                   0
# overall_rating                0
# potential                     0
# value_euro                  255
# wage_euro                   246
# preferred_foot                0
# release_clause_euro        1837
# club_team                    14
# club_rating                  14
# club_position                14
# national_team             17097
# national_rating           17097
# national_team_position    17097
# crossing                      0
# finishing                     0
# heading_accuracy              0
# short_passing                 0
# volleys                       0
# dribbling                     0
# curve                         0
# freekick_accuracy             0
# long_passing                  0
# ball_control                  0
# acceleration                  0
# sprint_speed                  0
# agility                       0
# reactions                     0
# balance                       0
# shot_power                    0
# jumping                       0
# stamina                       0
# strength                      0
# long_shots                    0
# aggression                    0
# interceptions                 0
# positioning                   0
# vision                        0
# penalties                     0
# composure                     0
# marking                       0
# standing_tackle               0
# sliding_tackle                0
# GK_diving                     0
# GK_handling                   0
# GK_kicking                    0
# GK_positioning                0
# GK_reflexes                   0
# dtype: int64

# %%
df.dropna(subset=['value_euro'], inplace=True)

# %%
df.isnull().sum()
# Out:
# name                          0
# age                           0
# height_cm                     0
# weight_kgs                    0
# nationality                   0
# overall_rating                0
# potential                     0
# value_euro                    0
# wage_euro                     0
# preferred_foot                0
# release_clause_euro        1582
# club_team                     0
# club_rating                   0
# club_position                 0
# national_team             16842
# national_rating           16842
# national_team_position    16842
# crossing                      0
# finishing                     0
# heading_accuracy              0
# short_passing                 0
# volleys                       0
# dribbling                     0
# curve                         0
# freekick_accuracy             0
# long_passing                  0
# ball_control                  0
# acceleration                  0
# sprint_speed                  0
# agility                       0
# reactions                     0
# balance                       0
# shot_power                    0
# jumping                       0
# stamina                       0
# strength                      0
# long_shots                    0
# aggression                    0
# interceptions                 0
# positioning                   0
# vision                        0
# penalties                     0
# composure                     0
# marking                       0
# standing_tackle               0
# sliding_tackle                0
# GK_diving                     0
# GK_handling                   0
# GK_kicking                    0
# GK_positioning                0
# GK_reflexes                   0
# dtype: int64

# %%
df['release_clause_euro'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                          0
# age                           0
# height_cm                     0
# weight_kgs                    0
# nationality                   0
# overall_rating                0
# potential                     0
# value_euro                    0
# wage_euro                     0
# preferred_foot                0
# release_clause_euro           0
# club_team                     0
# club_rating                   0
# club_position                 0
# national_team             16842
# national_rating           16842
# national_team_position    16842
# crossing                      0
# finishing                     0
# heading_accuracy              0
# short_passing                 0
# volleys                       0
# dribbling                     0
# curve                         0
# freekick_accuracy             0
# long_passing                  0
# ball_control                  0
# acceleration                  0
# sprint_speed                  0
# agility                       0
# reactions                     0
# balance                       0
# shot_power                    0
# jumping                       0
# stamina                       0
# strength                      0
# long_shots                    0
# aggression                    0
# interceptions                 0
# positioning                   0
# vision                        0
# penalties                     0
# composure                     0
# marking                       0
# standing_tackle               0
# sliding_tackle                0
# GK_diving                     0
# GK_handling                   0
# GK_kicking                    0
# GK_positioning                0
# GK_reflexes                   0
# dtype: int64

# %%
df['national_team'].fillna(0, inplace=True)

# %%
df['national_rating'].fillna(0, inplace=True)

# %%
df['national_team_position'].fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# name                      0
# age                       0
# height_cm                 0
# weight_kgs                0
# nationality               0
# overall_rating            0
# potential                 0
# value_euro                0
# wage_euro                 0
# preferred_foot            0
# release_clause_euro       0
# club_team                 0
# club_rating               0
# club_position             0
# national_team             0
# national_rating           0
# national_team_position    0
# crossing                  0
# finishing                 0
# heading_accuracy          0
# short_passing             0
# volleys                   0
# dribbling                 0
# curve                     0
# freekick_accuracy         0
# long_passing              0
# ball_control              0
# acceleration              0
# sprint_speed              0
# agility                   0
# reactions                 0
# balance                   0
# shot_power                0
# jumping                   0
# stamina                   0
# strength                  0
# long_shots                0
# aggression                0
# interceptions             0
# positioning               0
# vision                    0
# penalties                 0
# composure                 0
# marking                   0
# standing_tackle           0
# sliding_tackle            0
# GK_diving                 0
# GK_handling               0
# GK_kicking                0
# GK_positioning            0
# GK_reflexes               0
# dtype: int64

# %%
df.dtypes
# Out:
# name                       object
# age                         int64
# height_cm                 float64
# weight_kgs                float64
# nationality                object
# overall_rating              int64
# potential                   int64
# value_euro                float64
# wage_euro                 float64
# preferred_foot             object
# release_clause_euro       float64
# club_team                  object
# club_rating               float64
# club_position              object
# national_team              object
# national_rating           float64
# national_team_position     object
# crossing                    int64
# finishing                   int64
# heading_accuracy            int64
# short_passing               int64
# volleys                     int64
# dribbling                   int64
# curve                       int64
# freekick_accuracy           int64
# long_passing                int64
# ball_control                int64
# acceleration                int64
# sprint_speed                int64
# agility                     int64
# reactions                   int64
# balance                     int64
# shot_power                  int64
# jumping                     int64
# stamina                     int64
# strength                    int64
# long_shots                  int64
# aggression                  int64
# interceptions               int64
# positioning                 int64
# vision                      int64
# penalties                   int64
# composure                   int64
# marking                     int64
# standing_tackle             int64
# sliding_tackle              int64
# GK_diving                   int64
# GK_handling                 int64
# GK_kicking                  int64
# GK_positioning              int64
# GK_reflexes                 int64
# dtype: object

# %%
df.shape
# Out:
# (17699, 51)

# %% [markdown]
# # <span id="4"></span> Dealing with Categorical Data
# #### [Return Contents](#0)

# %% [markdown]
# We identified several categorical values in our dataset.  We decided to clean some of them up by transforming them into dummy numerical values. The most important was preferred foot, so we could answer the key question about left vs. right foot preference.  But the others turned out not to be worth the investment of time.  Position isn't a good indicator of the value of a new-comer and there turned out to be issues with the quality of the data in this cateogry.

# %%
cleanup_nationalposition  = { 'national_team_position': {'': 0, 'LS':1, 'ST':2, 'RS':3,'LW':4, 'LF':5, 'CF':6, 'RF':7, 'RW':8, 'LAM':9, 'CAM':10, 'RAM':11, 'LM':12, 'LCM':13, 'CM':14,
       'RCM':15, 'RM':16, 'LWB':17, 'LDM':18, 'CDM':19, 'RDM':20, 'RWB':21, 'LB':22, 'LCB':23, 'CB':24,
       'RCB':25, 'RB':26, 'SUB': 27, 'GK': 28, 'RES': 29}}

# %%
df.replace(cleanup_nationalposition, inplace=True)
df.head(100)
# Out:
#                  name  age  height_cm  weight_kgs           nationality  \
# id
# 158023       L. Messi   31 170.180000   72.100000             Argentina
# 190460     C. Eriksen   27 154.940000   76.200000               Denmark
# 195864       P. Pogba   25 190.500000   83.900000                France
# 198219     L. Insigne   27 162.560000   59.000000                 Italy
# 201024   K. Koulibaly   27 187.960000   88.900000               Senegal
# ...               ...  ...        ...         ...                   ...
# 201455   G. Kondogbia   26 187.960000   79.800000  Central African Rep.
# 202562  J. Roussillon   26 175.260000   79.800000                France
# 202685        S. Zaza   27 185.420000   83.900000                 Italy
# 203890    S. Vrsaljko   27 154.940000   76.200000               Croatia
# 204024      C. Kramer   28 190.500000   76.200000               Germany
#
#         overall_rating  potential       value_euro     wage_euro  \
# id
# 158023              94         94 110500000.000000 565000.000000
# 190460              88         89  69500000.000000 205000.000000
# 195864              88         91  73000000.000000 255000.000000
# 198219              88         88  62000000.000000 165000.000000
# 201024              88         91  60000000.000000 135000.000000
# ...                ...        ...              ...           ...
# 201455              81         84  22000000.000000  43000.000000
# 202562              81         83  18000000.000000  50000.000000
# 202685              81         82  21000000.000000  48000.000000
# 203890              81         81  15000000.000000  57000.000000
# 204024              81         82  17000000.000000  35000.000000
#
#        preferred_foot  release_clause_euro                 club_team  \
# id
# 158023           Left     226500000.000000              FC Barcelona
# 190460          Right     133800000.000000         Tottenham Hotspur
# 195864          Right     144200000.000000         Manchester United
# 198219          Right     105400000.000000                    Napoli
# 201024          Right     106500000.000000                    Napoli
# ...               ...                  ...                       ...
# 201455           Left      47900000.000000               Valencia CF
# 202562           Left      32000000.000000             VfL Wolfsburg
# 202685           Left             0.000000                    Torino
# 203890          Right             0.000000                     Inter
# 204024          Right      30200000.000000  Borussia Mönchengladbach
#
#         club_rating club_position national_team  national_rating  \
# id
# 158023    86.000000            RW     Argentina        82.000000
# 190460    83.000000           LCM       Denmark        78.000000
# 195864    82.000000           LCM        France        84.000000
# 198219    82.000000            LS         Italy        83.000000
# 201024    82.000000           LCB             0         0.000000
# ...             ...           ...           ...              ...
# 201455    80.000000           LCM             0         0.000000
# 202562    77.000000            LB             0         0.000000
# 202685    77.000000            RS             0         0.000000
# 203890    82.000000           SUB             0         0.000000
# 204024    79.000000           SUB             0         0.000000
#
#         national_team_position  crossing  finishing  heading_accuracy  \
# id
# 158023                       7        86         95                70
# 190460                      10        88         81                52
# 195864                      20        80         75                75
# 198219                       4        86         77                56
# 201024                       0        30         22                83
# ...                        ...       ...        ...               ...
# 201455                       0        65         69                75
# 202562                       0        81         64                71
# 202685                       0        52         80                79
# 203890                       0        82         44                73
# 204024                       0        61         46                58
#
#         short_passing  volleys  dribbling  curve  freekick_accuracy  \
# id
# 158023             92       86         97     93                 94
# 190460             91       80         84     86                 87
# 195864             86       85         87     85                 82
# 198219             85       74         90     87                 77
# 201024             68       14         69     28                 28
# ...               ...      ...        ...    ...                ...
# 201455             81       62         78     62                 56
# 202562             77       57         79     75                 56
# 202685             71       81         77     71                 56
# 203890             77       53         74     70                 57
# 204024             80       58         71     54                 51
#
#         long_passing  ball_control  acceleration  sprint_speed  agility  \
# id
# 158023            89            96            91            86       93
# 190460            89            91            76            73       80
# 195864            90            90            71            79       76
# 198219            78            93            94            86       94
# 201024            60            63            70            75       50
# ...              ...           ...           ...           ...      ...
# 201455            79            83            69            76       76
# 202562            70            79            87            85       77
# 202685            45            79            77            79       76
# 203890            70            79            78            79       67
# 204024            72            81            52            52       66
#
#         reactions  balance  shot_power  jumping  stamina  strength  \
# id
# 158023         95       95          85       68       72        66
# 190460         88       81          84       50       92        58
# 195864         82       66          90       83       88        87
# 198219         83       93          75       53       75        44
# 201024         82       40          55       81       75        94
# ...           ...      ...         ...      ...      ...       ...
# 201455         83       67          86       81       78        91
# 202562         76       78          75       73       84        77
# 202685         78       69          85       89       76        88
# 203890         79       72          75       85       87        73
# 204024         85       54          54       51       93        69
#
#         long_shots  aggression  interceptions  positioning  vision  penalties  \
# id
# 158023          94          48             22           94      94         75
# 190460          89          46             56           84      91         67
# 195864          82          78             64           82      88         82
# 198219          84          34             26           83      87         61
# 201024          15          87             88           24      49         33
# ...            ...         ...            ...          ...     ...        ...
# 201455          80          82             79           77      79         45
# 202562          65          75             77           71      71         51
# 202685          72          87             40           83      66         79
# 203890          58          75             80           65      68         52
# 204024          42          78             81           70      73         47
#
#         composure  marking  standing_tackle  sliding_tackle  GK_diving  \
# id
# 158023         96       33               28              26          6
# 190460         88       59               57              22          9
# 195864         87       63               67              67          5
# 198219         83       51               24              22          8
# 201024         80       91               88              87          7
# ...           ...      ...              ...             ...        ...
# 201455         82       78               82              82         15
# 202562         75       75               84              79          9
# 202685         72       54               42              50          7
# 203890         67       79               81              77         15
# 204024         78       80               80              76          8
#
#         GK_handling  GK_kicking  GK_positioning  GK_reflexes
# id
# 158023           11          15              14            8
# 190460           14           7               7            6
# 195864            6           2               4            3
# 198219            4          14               9           10
# 201024           11           7              13            5
# ...             ...         ...             ...          ...
# 201455           10          10               8           10
# 202562            7          13               8           15
# 202685           13           9               7            9
# 203890           11          10              10           12
# 204024           13           9               6            8
#
# [100 rows x 51 columns]

# %%
df['national_team_position'].astype(int)
# Out:
# id
# 158023     7
# 190460    10
# 195864    20
# 198219     4
# 201024     0
#           ..
# 204322     0
# 239762     0
# 235155     0
# 244883     0
# 247187     0
# Name: national_team_position, Length: 17699, dtype: int64

# %%
cleanup_clubposition  = { 'club_position': {'': 0, 'LS':1, 'ST':2, 'RS':3,'LW':4, 'LF':5, 'CF':6, 'RF':7, 'RW':8, 'LAM':9, 'CAM':10, 'RAM':11, 'LM':12, 'LCM':13, 'CM':14,
       'RCM':15, 'RM':16, 'LWB':17, 'LDM':18, 'CDM':19, 'RDM':20, 'RWB':21, 'LB':22, 'LCB':23, 'CB':24,
       'RCB':25, 'RB':26, 'SUB': 27, 'GK': 28, 'RES': 29}}

# %%
df.replace(cleanup_clubposition, inplace=True)
df.head()
# Out:
#                 name  age  height_cm  weight_kgs nationality  overall_rating  \
# id
# 158023      L. Messi   31 170.180000   72.100000   Argentina              94
# 190460    C. Eriksen   27 154.940000   76.200000     Denmark              88
# 195864      P. Pogba   25 190.500000   83.900000      France              88
# 198219    L. Insigne   27 162.560000   59.000000       Italy              88
# 201024  K. Koulibaly   27 187.960000   88.900000     Senegal              88
#
#         potential       value_euro     wage_euro preferred_foot  \
# id
# 158023         94 110500000.000000 565000.000000           Left
# 190460         89  69500000.000000 205000.000000          Right
# 195864         91  73000000.000000 255000.000000          Right
# 198219         88  62000000.000000 165000.000000          Right
# 201024         91  60000000.000000 135000.000000          Right
#
#         release_clause_euro          club_team  club_rating  club_position  \
# id
# 158023     226500000.000000       FC Barcelona    86.000000              8
# 190460     133800000.000000  Tottenham Hotspur    83.000000             13
# 195864     144200000.000000  Manchester United    82.000000             13
# 198219     105400000.000000             Napoli    82.000000              1
# 201024     106500000.000000             Napoli    82.000000             23
#
#        national_team  national_rating  national_team_position  crossing  \
# id
# 158023     Argentina        82.000000                       7        86
# 190460       Denmark        78.000000                      10        88
# 195864        France        84.000000                      20        80
# 198219         Italy        83.000000                       4        86
# 201024             0         0.000000                       0        30
#
#         finishing  heading_accuracy  short_passing  volleys  dribbling  curve  \
# id
# 158023         95                70             92       86         97     93
# 190460         81                52             91       80         84     86
# 195864         75                75             86       85         87     85
# 198219         77                56             85       74         90     87
# 201024         22                83             68       14         69     28
#
#         freekick_accuracy  long_passing  ball_control  acceleration  \
# id
# 158023                 94            89            96            91
# 190460                 87            89            91            76
# 195864                 82            90            90            71
# 198219                 77            78            93            94
# 201024                 28            60            63            70
#
#         sprint_speed  agility  reactions  balance  shot_power  jumping  \
# id
# 158023            86       93         95       95          85       68
# 190460            73       80         88       81          84       50
# 195864            79       76         82       66          90       83
# 198219            86       94         83       93          75       53
# 201024            75       50         82       40          55       81
#
#         stamina  strength  long_shots  aggression  interceptions  positioning  \
# id
# 158023       72        66          94          48             22           94
# 190460       92        58          89          46             56           84
# 195864       88        87          82          78             64           82
# 198219       75        44          84          34             26           83
# 201024       75        94          15          87             88           24
#
#         vision  penalties  composure  marking  standing_tackle  \
# id
# 158023      94         75         96       33               28
# 190460      91         67         88       59               57
# 195864      88         82         87       63               67
# 198219      87         61         83       51               24
# 201024      49         33         80       91               88
#
#         sliding_tackle  GK_diving  GK_handling  GK_kicking  GK_positioning  \
# id
# 158023              26          6           11          15              14
# 190460              22          9           14           7               7
# 195864              67          5            6           2               4
# 198219              22          8            4          14               9
# 201024              87          7           11           7              13
#
#         GK_reflexes
# id
# 158023            8
# 190460            6
# 195864            3
# 198219           10
# 201024            5

# %%
df['club_position'].astype(int)
# Out:
# id
# 158023     8
# 190460    13
# 195864    13
# 198219     1
# 201024    23
#           ..
# 204322    27
# 239762    22
# 235155    29
# 244883    29
# 247187    29
# Name: club_position, Length: 17699, dtype: int64

# %%
cleanup_foot  = { 'preferred_foot': {'Left': 0, 'Right':1}}

# %%
df.replace(cleanup_foot, inplace=True)
df.head()
# Out:
#                 name  age  height_cm  weight_kgs nationality  overall_rating  \
# id
# 158023      L. Messi   31 170.180000   72.100000   Argentina              94
# 190460    C. Eriksen   27 154.940000   76.200000     Denmark              88
# 195864      P. Pogba   25 190.500000   83.900000      France              88
# 198219    L. Insigne   27 162.560000   59.000000       Italy              88
# 201024  K. Koulibaly   27 187.960000   88.900000     Senegal              88
#
#         potential       value_euro     wage_euro  preferred_foot  \
# id
# 158023         94 110500000.000000 565000.000000               0
# 190460         89  69500000.000000 205000.000000               1
# 195864         91  73000000.000000 255000.000000               1
# 198219         88  62000000.000000 165000.000000               1
# 201024         91  60000000.000000 135000.000000               1
#
#         release_clause_euro          club_team  club_rating  club_position  \
# id
# 158023     226500000.000000       FC Barcelona    86.000000              8
# 190460     133800000.000000  Tottenham Hotspur    83.000000             13
# 195864     144200000.000000  Manchester United    82.000000             13
# 198219     105400000.000000             Napoli    82.000000              1
# 201024     106500000.000000             Napoli    82.000000             23
#
#        national_team  national_rating  national_team_position  crossing  \
# id
# 158023     Argentina        82.000000                       7        86
# 190460       Denmark        78.000000                      10        88
# 195864        France        84.000000                      20        80
# 198219         Italy        83.000000                       4        86
# 201024             0         0.000000                       0        30
#
#         finishing  heading_accuracy  short_passing  volleys  dribbling  curve  \
# id
# 158023         95                70             92       86         97     93
# 190460         81                52             91       80         84     86
# 195864         75                75             86       85         87     85
# 198219         77                56             85       74         90     87
# 201024         22                83             68       14         69     28
#
#         freekick_accuracy  long_passing  ball_control  acceleration  \
# id
# 158023                 94            89            96            91
# 190460                 87            89            91            76
# 195864                 82            90            90            71
# 198219                 77            78            93            94
# 201024                 28            60            63            70
#
#         sprint_speed  agility  reactions  balance  shot_power  jumping  \
# id
# 158023            86       93         95       95          85       68
# 190460            73       80         88       81          84       50
# 195864            79       76         82       66          90       83
# 198219            86       94         83       93          75       53
# 201024            75       50         82       40          55       81
#
#         stamina  strength  long_shots  aggression  interceptions  positioning  \
# id
# 158023       72        66          94          48             22           94
# 190460       92        58          89          46             56           84
# 195864       88        87          82          78             64           82
# 198219       75        44          84          34             26           83
# 201024       75        94          15          87             88           24
#
#         vision  penalties  composure  marking  standing_tackle  \
# id
# 158023      94         75         96       33               28
# 190460      91         67         88       59               57
# 195864      88         82         87       63               67
# 198219      87         61         83       51               24
# 201024      49         33         80       91               88
#
#         sliding_tackle  GK_diving  GK_handling  GK_kicking  GK_positioning  \
# id
# 158023              26          6           11          15              14
# 190460              22          9           14           7               7
# 195864              67          5            6           2               4
# 198219              22          8            4          14               9
# 201024              87          7           11           7              13
#
#         GK_reflexes
# id
# 158023            8
# 190460            6
# 195864            3
# 198219           10
# 201024            5

# %%
df['preferred_foot'].astype(int)
# Out:
# id
# 158023    0
# 190460    1
# 195864    1
# 198219    1
# 201024    1
#          ..
# 204322    1
# 239762    0
# 235155    1
# 244883    1
# 247187    1
# Name: preferred_foot, Length: 17699, dtype: int64

# %%
df.dtypes
# Out:
# name                       object
# age                         int64
# height_cm                 float64
# weight_kgs                float64
# nationality                object
# overall_rating              int64
# potential                   int64
# value_euro                float64
# wage_euro                 float64
# preferred_foot              int64
# release_clause_euro       float64
# club_team                  object
# club_rating               float64
# club_position               int64
# national_team              object
# national_rating           float64
# national_team_position      int64
# crossing                    int64
# finishing                   int64
# heading_accuracy            int64
# short_passing               int64
# volleys                     int64
# dribbling                   int64
# curve                       int64
# freekick_accuracy           int64
# long_passing                int64
# ball_control                int64
# acceleration                int64
# sprint_speed                int64
# agility                     int64
# reactions                   int64
# balance                     int64
# shot_power                  int64
# jumping                     int64
# stamina                     int64
# strength                    int64
# long_shots                  int64
# aggression                  int64
# interceptions               int64
# positioning                 int64
# vision                      int64
# penalties                   int64
# composure                   int64
# marking                     int64
# standing_tackle             int64
# sliding_tackle              int64
# GK_diving                   int64
# GK_handling                 int64
# GK_kicking                  int64
# GK_positioning              int64
# GK_reflexes                 int64
# dtype: object

# %% [markdown]
# # <span id="5"></span> Removing Outliers
# #### [Return Contents](#0)

# %% [markdown]
# We decided to remove the top 2.5% and bottom 2.5% from the dataset, which turned out to greatly improve the results of our hypothesis tests.  The chance of coming across a superstar who will be in the top 2.5% is not as likely as a good player who falls between the 25-75% quartiles.  So we decided to train our models to be more sensitive to the average player.

# %%
upper_q = df['value_euro'].quantile(.975)
upper_q
# Out:
# 15500000.0

# %%
df = df[df['value_euro'] < upper_q]

# %%
df.describe()
# Out:
#                age    height_cm   weight_kgs  overall_rating    potential  \
# count 17244.000000 17244.000000 17244.000000    17244.000000 17244.000000
# mean     25.507249   174.917680    75.265037       65.787578    71.079796
# std       4.724861    14.036025     7.069842        6.498466     5.749665
# min      17.000000   152.400000    49.900000       47.000000    50.000000
# 25%      22.000000   154.940000    69.900000       62.000000    67.000000
# 50%      25.000000   175.260000    74.800000       66.000000    71.000000
# 75%      29.000000   185.420000    79.800000       70.000000    75.000000
# max      46.000000   205.740000   110.200000       88.000000    90.000000
#
#            value_euro     wage_euro  preferred_foot  release_clause_euro  \
# count    17244.000000  17244.000000    17244.000000         17244.000000
# mean   1772110.879146   7626.188819        0.767861       2886307.701229
# std    2642629.102425  11729.535338        0.422209       4909870.283825
# min      10000.000000   1000.000000        0.000000             0.000000
# 25%     325000.000000   1000.000000        1.000000        371000.000000
# 50%     675000.000000   3000.000000        1.000000        960000.000000
# 75%    1800000.000000   8000.000000        1.000000       2600000.000000
# max   15000000.000000 120000.000000        1.000000      36800000.000000
#
#        club_rating  club_position  national_rating  national_team_position  \
# count 17244.000000   17244.000000     17244.000000            17244.000000
# mean     69.050220      23.577128         2.784737                0.836407
# std       4.768506       7.141166        14.169844                4.481395
# min      54.000000       1.000000         0.000000                0.000000
# 25%      65.000000      23.000000         0.000000                0.000000
# 50%      69.000000      27.000000         0.000000                0.000000
# 75%      72.000000      27.000000         0.000000                0.000000
# max      86.000000      29.000000        85.000000               29.000000
#
#           crossing    finishing  heading_accuracy  short_passing      volleys  \
# count 17244.000000 17244.000000      17244.000000   17244.000000 17244.000000
# mean     49.291000    44.906460         51.902401      58.129378    42.271863
# std      18.238946    19.343458         17.365943      14.590862    17.424745
# min       5.000000     2.000000          4.000000       7.000000     3.000000
# 25%      37.000000    29.000000         44.000000      53.000000    30.000000
# min        5.000000     12.000000     12.000000    11.000000    24.000000
# 25%       55.000000     58.000000     58.000000    56.000000    56.000000
# 50%       63.000000     68.000000     68.000000    66.000000    62.000000
# 75%       69.000000     75.000000     75.000000    74.000000    68.000000
# max       88.000000     97.000000     96.000000    95.000000    86.000000
#
#            balance   shot_power      jumping      stamina     strength  \
# count 16714.000000 16714.000000 16714.000000 16714.000000 16714.000000
# mean     63.967752    55.538590    65.090762    63.434067    65.325954
# std      13.976503    16.819332    11.603270    15.446067    12.437261
# min      16.000000     2.000000    15.000000    12.000000    20.000000
# 25%      56.000000    46.000000    58.000000    57.000000    58.000000
# 50%      66.000000    59.000000    66.000000    67.000000    67.000000
# 75%      74.000000    68.000000    73.000000    74.000000    74.000000
# max      96.000000    95.000000    94.000000    95.000000    97.000000
#
#         long_shots   aggression  interceptions  positioning       vision  \
# count 16714.000000 16714.000000   16714.000000 16714.000000 16714.000000
# mean     47.035300    56.041103      46.867476    50.062822    53.366758
# std      18.864945    17.129766      20.518586    19.090666    13.649908
# min       3.000000    11.000000       3.000000     2.000000    10.000000
# 25%      33.000000    44.000000      26.000000    39.000000    44.000000
# 50%      51.000000    59.000000      53.000000    55.000000    55.000000
# 75%      62.000000    69.000000      64.000000    64.000000    64.000000
# max      89.000000    95.000000      90.000000    90.000000    86.000000
#
#          penalties    composure      marking  standing_tackle  sliding_tackle  \
# count 16714.000000 16714.000000 16714.000000     16714.000000    16714.000000
# mean     48.487316    58.645148    47.353476        48.005624       45.958059
# std      15.372395    10.940728    19.769324        21.429273       21.073104
# min       5.000000    12.000000     3.000000         2.000000        3.000000
# 25%      39.000000    52.000000    30.000000        27.000000       24.000000
# 50%      49.000000    60.000000    53.000000        56.000000       53.000000
# 75%      60.000000    66.000000    64.000000        66.000000       64.000000
# max      90.000000    90.000000    94.000000        88.000000       88.000000
#
#          GK_diving  GK_handling   GK_kicking  GK_positioning  GK_reflexes
# count 16714.000000 16714.000000 16714.000000    16714.000000 16714.000000
# mean     16.418452    16.195405    16.035778       16.191217    16.516693
# std      17.508305    16.703094    16.315941       16.840751    17.795218
# min       1.000000     1.000000     1.000000        1.000000     1.000000
# 25%       8.000000     8.000000     8.000000        8.000000     8.000000
# 50%      11.000000    11.000000    11.000000       11.000000    11.000000
# 75%      14.000000    14.000000    14.000000       14.000000    14.000000
# max      87.000000    87.000000    85.000000       90.000000    86.000000

# %%
df.shape
# Out:
# (16714, 51)

# %% [markdown]
# # <span id="6"></span> Checking for Target Correlation & Linearity
# #### [Return Contents](#0)

# %% [markdown]
# There are some feature variables with a decent correlation with the target of player value.  However, not many of these features follow a linear relationship.  A curvalinear, exponential relationship is more common among the features.

# %%
corr = df.corr()

# %%
df.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kgs', 'nationality',
#        'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'release_clause_euro', 'club_team', 'club_rating',
#        'club_position', 'national_team', 'national_rating',
#        'national_team_position', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes'],
#       dtype='object')

# %%
all_features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'wage_euro', 'preferred_foot', 'release_clause_euro', 'club_rating', 'club_position', 'national_rating',
       'national_team_position', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes']

# %%
#break the colums in to groups to plot 4 on a row at a time
n = 4
row_groups= [all_features[i:i+n] for i in range(0, len(all_features), n)]

# %%
for i in row_groups:
    pp = sns.pairplot(data=df, y_vars=['value_euro'],x_vars=i, kind="reg", height=6)

# %% [markdown]
# # <span id="7"></span> Checking for Feature Correlation
# #### [Return Contents](#0)

# %% [markdown]
# Several of the characteristic features are correlated, which could pose a problem with multicollinearity.

# %%
corr = df.corr()

# %%
def CorrMtx(df, dropDuplicates = True):
    if dropDuplicates:    
        mask = np.zeros_like(df, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True

    # Set background color / chart style
    sns.set_style(style = 'white')

    # Set up  matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Add diverging colormap from red to blue
    cmap = sns.diverging_palette(250, 10, as_cmap=True)

    # Draw correlation plot with or without duplicates
    if dropDuplicates:
        sns.heatmap(df, mask=mask, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)
    else:
        sns.heatmap(df, cmap=cmap, 
                square=True,
                linewidth=.5, cbar_kws={"shrink": .5}, ax=ax)


CorrMtx(corr, dropDuplicates = True)

# %%
corr
# Out:
#                              age  height_cm  weight_kgs  overall_rating  \
# age                     1.000000   0.049838    0.226949        0.495486
# height_cm               0.049838   1.000000    0.491692        0.038037
# weight_kgs              0.226949   0.491692    1.000000        0.159726
# overall_rating          0.495486   0.038037    0.159726        1.000000
# potential              -0.318880   0.011873   -0.023173        0.557055
# value_euro              0.113762   0.011228    0.061307        0.750368
# wage_euro               0.218830   0.023896    0.085505        0.638179
# preferred_foot          0.006052   0.049293    0.073220       -0.036517
# release_clause_euro     0.098508   0.010247    0.051462        0.666618
# club_rating            -0.003542   0.030774    0.055793        0.538763
# club_position          -0.171383   0.079460    0.041042       -0.270268
# national_rating         0.049740   0.021764    0.059794        0.237390
# national_team_position  0.048246   0.032710    0.063540        0.216911
# crossing                0.138309  -0.395796   -0.402805        0.352693
# finishing               0.074622  -0.299348   -0.299505        0.286312
# heading_accuracy        0.161786  -0.033863    0.038831        0.318710
# short_passing           0.140817  -0.298350   -0.302007        0.456691
# volleys                 0.151654  -0.281867   -0.268051        0.344073
# dribbling               0.016129  -0.390132   -0.424362        0.322973
# curve                   0.154437  -0.350948   -0.354256        0.377660
# freekick_accuracy       0.204937  -0.317228   -0.308539        0.360345
# long_passing            0.191117  -0.269668   -0.267972        0.446959
# ball_control            0.092278  -0.337108   -0.350600        0.409089
# acceleration           -0.154246  -0.412542   -0.489464        0.141922
# sprint_speed           -0.147383  -0.357548   -0.421955        0.155210
# agility                -0.012353  -0.446345   -0.543700        0.219236
# reactions               0.487912  -0.023634    0.084770        0.829870
# balance                -0.083337  -0.534362   -0.668650        0.071378
# shot_power              0.165268  -0.240220   -0.198994        0.403528
# jumping                 0.190760  -0.052446    0.004965        0.254556
# stamina                 0.116210  -0.254393   -0.229760        0.324599
# strength                0.340330   0.322840    0.616740        0.347956
# long_shots              0.168331  -0.309960   -0.283487        0.382973
# aggression              0.274728  -0.069852    0.029431        0.381482
# interceptions           0.206357  -0.075752   -0.028627        0.307741
# positioning             0.091655  -0.358288   -0.361201        0.312213
# vision                  0.194306  -0.297524   -0.295745        0.452838
# penalties               0.151961  -0.271411   -0.252952        0.301793
# composure               0.403141  -0.119387   -0.049719        0.691230
# marking                 0.151597  -0.086526   -0.052219        0.272834
# standing_tackle         0.125775  -0.077557   -0.049678        0.239310
# sliding_tackle          0.110199  -0.082971   -0.060404        0.214838
# reactions                 -0.054909   -0.056652       -0.047566    -0.052105
# balance                   -0.502971   -0.500398       -0.500576    -0.503293
# shot_power                -0.654669   -0.650080       -0.651511    -0.654188
# jumping                   -0.191984   -0.192576       -0.187925    -0.189919
# stamina                   -0.710304   -0.706749       -0.707464    -0.712161
# strength                  -0.105273   -0.105675       -0.098805    -0.103571
# long_shots                -0.610656   -0.605583       -0.606831    -0.609828
# aggression                -0.580568   -0.577927       -0.576185    -0.580952
# interceptions             -0.483929   -0.483224       -0.479568    -0.484515
# positioning               -0.681978   -0.677702       -0.679942    -0.682741
# vision                    -0.376896   -0.372048       -0.374570    -0.379054
# penalties                 -0.617260   -0.611676       -0.615412    -0.616874
# composure                 -0.403622   -0.401436       -0.397593    -0.404965
# marking                   -0.549694   -0.547451       -0.545181    -0.550342
# standing_tackle           -0.530811   -0.530602       -0.527218    -0.531792
# sliding_tackle            -0.509279   -0.509061       -0.505394    -0.509743
# GK_diving                  0.969952    0.965973        0.969796     0.972947
# GK_handling                1.000000    0.965354        0.969015     0.969983
# GK_kicking                 0.965354    1.000000        0.964870     0.966624
# GK_positioning             0.969015    0.964870        1.000000     0.970123
# GK_reflexes                0.969983    0.966624        0.970123     1.000000

# %% [markdown]
# # <span id="8"></span> Recording Correlations
# #### [Return Contents](#0)
# <hr/>

# %% [markdown]
# We found the following variables had a decent correlation with the target: overall rating, potential, reactions, and  composure.  These were followed up by short_passing, long_passing, ball_control, shot_power, and vision.  We also found there were several of the 24 characteristic features that were correlated, so we plan to find a solution to protect against multicollinearity.

# %%
var = 'potential'
data = pd.concat([df['value_euro'], df[var]], axis=1)
data.plot.scatter(x=var, y='value_euro', ylim=(3,13000000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'overall_rating'
data = pd.concat([df['value_euro'], df[var]], axis=1)
data.plot.scatter(x=var, y='value_euro', ylim=(3,13000000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'reactions'
data = pd.concat([df['value_euro'], df[var]], axis=1)
data.plot.scatter(x=var, y='value_euro', ylim=(3,13000000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
var = 'composure'
data = pd.concat([df['value_euro'], df[var]], axis=1)
data.plot.scatter(x=var, y='value_euro', ylim=(3,13000000));
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # Hypothesis Tests

# %% [markdown]
# # <span id="9"></span> Left vs. Right Foot
# #### [Return Contents](#0)

# %% [markdown]
# Is there is a difference in the value between right footed and left footed players?
#
# ***Null Hypothesis***: there is not a statistically significant difference between the value of right and left footed players.
#
# ***Alternative Hypothesis***: there is a statistically significant difference between the value of right and left footed players.
#
# We used a two-sample, two-tailed independent T-test to determine if there is a significant difference between the value of the two groups.
#
# We started by determining the sample size requirements to achieve an effect size of 0.8 and a power of 0.8 with an alpha value of 0.025.

# %%
from statsmodels.stats.power import TTestIndPower
effect_size = 0.8
alpha = 0.025 # significance level
power = 0.8

power_analysis = TTestIndPower()
sample_size = power_analysis.solve_power(effect_size = effect_size, 
                                         power = power, 
                                         alpha = alpha)
sample_size
# Out:
# 30.994809182633027

# %% [markdown]
# According to these calculations, we need a sample size of at least 31 observations to achieve our ideal statistical power.  Fortunately, we have 17,699 observations in our data set so we will be able to meet this requirement.

# %%
from scipy.stats import ttest_ind
foot_df = df[['value_euro','preferred_foot']]
left = foot_df[foot_df['preferred_foot']==0]
right = foot_df[foot_df['preferred_foot']==1]

t_score, pvalue = ttest_ind(left['value_euro'],right['value_euro'], equal_var= False)

print("P-value",float(pvalue))
print("t-Score",float(t_score))

alpha= 0.025
if pvalue<alpha:
    print("reject null hypothesis")
else:
    print("fail to reject the null hypothesis")
# Out:
# P-value 0.07171615939886139
# t-Score 1.8012098199198197
# fail to reject the null hypothesis

# %% [markdown]
# ### Fail to Reject Null Hypthesis: There isn't a significant difference.
#
# Based on the results of this two-tailed t-test, we determined that there isn't a statistically significant difference between the value of right and left footed players.  The average value of left footed players is slightly higher than the average value of right footed players, but the difference is not large enough.  This indicates that the old recruiters, who very much believed that left foots are more valuable, were actually wrong in limiting their search to only left footed players.

# %%
df[df['preferred_foot'] == 0].max()
# Out:
# name                      Óscar Whalley
# age                                  40
# height_cm                         203.2
# weight_kgs                         98.9
# nationality                    Zimbabwe
# overall_rating                       83
# potential                            90
# value_euro                      1.5e+07
# wage_euro                        120000
# preferred_foot                        0
# release_clause_euro            3.34e+07
# club_team                 Śląsk Wrocław
# club_rating                          86
# club_position                        29
# national_rating                      85
# national_team_position               29
# crossing                             90
# finishing                            82
# heading_accuracy                     91
# short_passing                        85
# volleys                              88
# dribbling                            88
# curve                                88
# freekick_accuracy                    89
# long_passing                         86
# ball_control                         87
# acceleration                         94
# sprint_speed                         94
# agility                              95
# reactions                            86
# balance                              96
# shot_power                           95
# jumping                              93
# stamina                              94
# strength                             93
# long_shots                           87
# aggression                           94
# interceptions                        85
# positioning                          85
# vision                               85
# penalties                            90
# composure                            90
# marking                              86
# standing_tackle                      86
# sliding_tackle                       85
# GK_diving                            87
# GK_handling                          84
# GK_kicking                           81
# GK_positioning                       85
# GK_reflexes                          84
# dtype: object

# %%
pd.set_option('float_format', '{:f}'.format)
df[df['preferred_foot'] == 0].describe()
# Out:
#               age   height_cm  weight_kgs  overall_rating   potential  \
# count 3927.000000 3927.000000 3927.000000     3927.000000 3927.000000
# mean    25.495798  173.654632   74.330074       66.596639   71.673287
# std      4.503739   13.677195    6.875394        5.781888    5.559199
# min     17.000000  152.400000   49.900000       51.000000   55.000000
# 25%     22.000000  154.940000   69.900000       63.000000   68.000000
# 50%     25.000000  175.260000   73.900000       67.000000   71.000000
# 75%     29.000000  185.420000   78.900000       71.000000   75.000000
# max     40.000000  203.200000   98.900000       83.000000   90.000000
#
#            value_euro     wage_euro  preferred_foot  release_clause_euro  \
# count     3927.000000   3927.000000     3927.000000          3927.000000
# mean   1893763.687293   8138.018844        0.000000       3089216.959511
# std    2674003.507610  11795.260471        0.000000       5004983.426967
# min      80000.000000   1000.000000        0.000000             0.000000
# 25%     400000.000000   2000.000000        0.000000        457000.000000
# 50%     750000.000000   4000.000000        0.000000       1100000.000000
# 75%    2100000.000000   9000.000000        0.000000       2900000.000000
# max   15000000.000000 120000.000000        0.000000      33400000.000000
#
#        club_rating  club_position  national_rating  national_team_position  \
# %%
df[df['value_euro'] == 108000000.00]
# Out:
# Empty DataFrame
# Columns: [name, age, height_cm, weight_kgs, nationality, overall_rating, potential, value_euro, wage_euro, preferred_foot, release_clause_euro, club_team, club_rating, club_position, national_team, national_rating, national_team_position, crossing, finishing, heading_accuracy, short_passing, volleys, dribbling, curve, freekick_accuracy, long_passing, ball_control, acceleration, sprint_speed, agility, reactions, balance, shot_power, jumping, stamina, strength, long_shots, aggression, interceptions, positioning, vision, penalties, composure, marking, standing_tackle, sliding_tackle, GK_diving, GK_handling, GK_kicking, GK_positioning, GK_reflexes]
# Index: []

# %%
left_foot_val = float(2.656160e+06)

# %%
left_foot_val
# Out:
# 2656160.0

# %%
right_foot_val = float(2.425613e+06)
right_foot_val
# Out:
# 2425613.0

# %%
df[df['preferred_foot'] == 1].mean()
# Out:
# age                           25.561664
# height_cm                    175.284234
# weight_kgs                    75.549144
# overall_rating                66.069837
# potential                     71.272386
# value_euro               1805972.472042
# wage_euro                   7733.870337
# preferred_foot                 1.000000
# release_clause_euro      2939332.994447
# club_rating                   69.096035
# club_position                 23.477751
# national_rating                2.874482
# national_team_position         0.864315
# crossing                      47.875811
# finishing                     45.151951
# heading_accuracy              52.108470
# short_passing                 57.950575
# volleys                       42.391570
# dribbling                     54.224290
# curve                         45.647376
# freekick_accuracy             41.367248
# long_passing                  51.912176
# ball_control                  57.486744
# acceleration                  64.042856
# sprint_speed                  64.205443
# agility                       62.784390
# reactions                     61.618206
# balance                       63.249941
# shot_power                    54.876828
# jumping                       65.259482
# stamina                       62.678814
# strength                      65.633065
# long_shots                    46.251114
# aggression                    55.543755
# interceptions                 45.733479
# positioning                   49.106358
# vision                        52.924689
# penalties                     47.997419
# composure                     58.329944
# marking                       46.211387
# standing_tackle               46.695316
# sliding_tackle                44.542035
# GK_diving                     17.395011
# GK_handling                   17.138344
# GK_kicking                    16.978103
# GK_positioning                17.153828
# GK_reflexes                   17.533276
# dtype: float64

# %%
fifa_feet = df[['preferred_foot','value_euro']]

# %%
foot_value = fifa_feet.groupby('preferred_foot').agg({'value_euro': ['mean']})
foot_value
# Out:
#                    value_euro
#                          mean
# preferred_foot
# 0              1893763.687293
# 1              1805972.472042

# %%
foot_value.values.flatten()
# Out:
# array([1893763.6872931 , 1805972.47204192])

# %%
fig, ax = plt.subplots()

# Plot a bar-chart of gold medals as a function of country
ax.bar(['Left Foot','Right Foot'],foot_value.values.flatten())

# Set the x-axis tick labels to the country names
#
#ax.set_xlabel('Foot')
# Set the y-axis label
ax.set_ylabel('Player Value')

ax.set_title('Player Value by Preferred Foot')

plt.show()

# %% [markdown]
# # <span id="10"></span> Age Group Comparison
# #### [Return Contents](#0)
# <hr/>

# %% [markdown]
# Is there is a difference in value between age group 16-19 (new-comers) and age group 30-39 (veterans)?
#
# ***Null Hypothesis***: there is not a statistically significant difference between the value of new-comers and veterans.
#
# ***Alternative Hypothesis***: there is a statistically significant difference between the value of new-comers and veterans.
#
# We used a two-sample, two-tailed independent T-test to determine if there is a significant difference between the value of the two groups.
#
# We started by determining the sample size requirements to achieve an effect size of 0.8 and a power of 0.8 with an alpha value of 0.025.

# %%
from statsmodels.stats.power import TTestIndPower
effect_size = 0.8
alpha = 0.025 # significance level
power = 0.8

power_analysis = TTestIndPower()
sample_size = power_analysis.solve_power(effect_size = effect_size, 
                                         power = power, 
                                         alpha = alpha)
sample_size
# Out:
# 30.994809182633027

# %% [markdown]
# According to these calculations, we need a sample size of at least 31 observations to achieve our ideal statistical power.  Fortunately, we have 17,699 observations in our data set so we will be able to meet this requirement.

# %%
df_age = df[['age','value_euro']]
bins = [16,20, 30, 40,50]
labels = ['16-19', '20-29','30-39' ,'40-49']
df_age['age_range'] = pd.cut(df_age.age, bins=bins, labels=labels ,include_lowest = True)

# %%
avg_age_value = df_age.groupby('age_range').agg({'value_euro': ['mean']})
avg_age_value
# Out:
#               value_euro
#                     mean
# age_range
# 16-19      750950.298211
# 20-29     2068407.682235
# 30-39     1803914.233577
# 40-49     1201250.000000

# %%
avg_age_value.reset_index(inplace=True)

# %%
agerange_num  = { 'age_range': { '16-19':1 , '20-29':2, '30-39':3,'40-49':4}}

# %%
avg_age_value.replace(agerange_num, inplace=True)

# %%
avg_age_value.loc[0]
# Out:
# age_range               1.000000
# value_euro  mean   750950.298211
# Name: 0, dtype: float64

# %%
foot_value.values.flatten()
# Out:
# array([1893763.6872931 , 1805972.47204192])

# %%
#ha: there is statistical difference between the value of players between the age range 16-19 and 30-39 
#ho: there is no statistical difference between the value of players between the age range 16-19 and 30-39  

age_df = avg_age_value[['age_range','value_euro']]
agerange16_19= avg_age_value.loc[0]
agerange30_39= avg_age_value.loc[2]

statistic, pvalue = ttest_ind(agerange16_19,agerange30_39, equal_var= False,)
alpha = 0.025

print("Pvalue:", float(pvalue)) 
print("Tstat:", float(statistic)) 
if pvalue < alpha:
    print("Null hypothesis rejected, there is a statistical significance the value of players between the age range 16-19 and 30-39 ")
else:
    print("Fail to reject null hypothesis there is no statistical significance between the value of players between the age range 16-19 and 30-39 ")
# Out:
# Pvalue: 0.6659110270427042
# Tstat: -0.5388838752149757
# Fail to reject null hypothesis there is no statistical significance between the value of players between the age range 16-19 and 30-39

# %% [markdown]
# ### Fail to Reject Null Hypthesis: There isn't a significant difference.
#
# Based on the results of this two-tailed t-test, we determined there isn't a statistically significant difference between the value of new-comers and veterans.  The average value of veterans is slightly higher than the average value of new-comers, but the difference is not large enough to be significant.  This means that a veteran player could be as cost effective as a new-comer.

# %%
fig, ax = plt.subplots()
# Plot a bar-chart of gold medals as a function of country
ax.bar(['16-19', '20-29','30-39' ,'40-49'],avg_age_value.values.flatten())
# Set the x-axis tick labels to the country names
#
ax.set_xlabel('Age Range')
# Set the y-axis label
ax.set_ylabel('Value in Euro')
ax.set_yticks(np.arange(0, 2300000, step=1000000))
ax.set_title('Value between Age Groups')
plt.savefig('graph.png',dpi=100,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # <span id="11"></span> Feature Engineering
# #### [Return Contents](#0)

# %% [markdown]
# We analyzed the features to identify new features we could engineer that might have a stronger influence on the model.  To protect the model from multicollinearity, we decided to aggregate the 24 characteristics into 6 different groups.

# %%
#attacking
df['attacking'] = df[['crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys']].mean(axis=1)

# %%
#skill
df['skill'] = df[['dribbling', 'curve', 'freekick_accuracy', 'long_passing', 'ball_control']].mean(axis=1)

# %%
#movement
df['movement'] = df[['acceleration', 'sprint_speed', 'agility', 'reactions', 'balance']].mean(axis=1)

# %%
#power
df['power'] = df[['shot_power', 'jumping', 'stamina', 'strength', 'long_shots']].mean(axis=1)

# %%
#mentality
df['mentality'] = df[['aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure']].mean(axis=1)

# %%
#defending
df['defending'] = df[['marking', 'standing_tackle', 'sliding_tackle']].mean(axis=1)

# %%
#goal_keeping
df['goal_keeping'] = df[['GK_diving', 'GK_handling',	'GK_kicking', 'GK_positioning',	'GK_reflexes']].mean(axis=1)

# %%
df
# Out:
#                     name  age  height_cm  weight_kgs   nationality  \
# id
# 41236     Z. Ibrahimović   37 195.580000   94.800000        Sweden
# 230168  Raphaelito Anjos   31 190.500000   84.800000        Brazil
# 230225    Juiano Mestres   35 154.940000   82.100000        Brazil
# 183498         M. Parolo   34 182.880000   74.800000         Italy
# 203890       S. Vrsaljko   27 154.940000   76.200000       Croatia
# ...                  ...  ...        ...         ...           ...
# 204322       R. McKenzie   25 175.260000   74.800000      Scotland
# 239762         M. Sipľak   23 182.880000   79.800000      Slovakia
# 235155        J. Bekkema   22 185.420000   89.800000   Netherlands
# 244883        A. Al Yami   21 175.260000   64.900000  Saudi Arabia
# 247187    Júnior Brumado   19 190.500000   79.800000        Brazil
#
#         overall_rating  potential      value_euro    wage_euro  \
# id
# 41236               85         85 14000000.000000 15000.000000
# 230168              82         82 14000000.000000 32000.000000
# 230225              82         82  6500000.000000 39000.000000
# 183498              82         82  9000000.000000 59000.000000
# 203890              81         81 15000000.000000 57000.000000
# ...                ...        ...             ...          ...
# 204322              67         70   975000.000000  3000.000000
# 239762              59         67   190000.000000  1000.000000
# 235155              59         67   170000.000000  1000.000000
# 244883              59         71   280000.000000  4000.000000
# 247187              59         75   325000.000000  2000.000000
#
#         preferred_foot  release_clause_euro       club_team  club_rating  \
# id
# 41236                1      21000000.000000       LA Galaxy    71.000000
# 230168               1      25200000.000000          Grêmio    75.000000
# 230225               1      12400000.000000        Cruzeiro    73.000000
# 183498               1      15300000.000000           Lazio    80.000000
# 203890               1             0.000000           Inter    82.000000
# ...                ...                  ...             ...          ...
# 204322               1       1800000.000000      Kilmarnock    67.000000
# 239762               0        295000.000000        Cracovia    65.000000
# 235155               1        289000.000000   SC Heerenveen    69.000000
# 244883               1        532000.000000        Al Hilal    74.000000
# 247187               1        626000.000000  FC Midtjylland    71.000000
#
#         club_position national_team  national_rating  national_team_position  \
# id
# 41236               3             0         0.000000                       0
# 230168             28        Brazil        81.000000                      28
# 230225             25        Brazil        81.000000                      25
# 183498             20             0         0.000000                       0
# 203890             27             0         0.000000                       0
# ...               ...           ...              ...                     ...
# 204322             27             0         0.000000                       0
# 239762             22             0         0.000000                       0
# 235155             29             0         0.000000                       0
# 244883             29             0         0.000000                       0
# 247187             29             0         0.000000                       0
#
#         crossing  finishing  heading_accuracy  short_passing  volleys  \
# id
# 41236         73         86                83             79       86
# 230168        10          8                11             18        8
# 230225        40         56                83             67       63
# 183498        70         70                75             80       76
# 203890        82         44                73             77       53
# ...          ...        ...               ...            ...      ...
# 204322        57         61                60             66       37
# 239762        50         19                53             55       31
# 235155        11          9                13             26        9
# 244883        42         60                55             49       49
# 247187        32         58                58             47       39
#
#         dribbling  curve  freekick_accuracy  long_passing  ball_control  \
# id
# 41236          79     82                 82            73            84
# 230168          9      9                 18            16            21
# 230225         60     72                 58            58            64
# 183498         75     67                 55            83            79
# 203890         74     70                 57            70            79
# ...           ...    ...                ...           ...           ...
# 204322         64     53                 47            61            66
# 239762         52     26                 28            43            53
# 235155         12     13                 12            24            18
# 244883         57     47                 39            37            56
# 247187         58     35                 25            37            56
#
#         acceleration  sprint_speed  agility  reactions  balance  shot_power  \
# id
# 41236             58            59       75         82       39          90
# 230168            41            42       34         82       41          21
# 230225            68            74       61         78       63          74
# 183498            68            69       67         82       71          87
# 203890            78            79       67         79       72          75
# ...              ...           ...      ...        ...      ...         ...
# 204322            83            86       93         63       82          51
# 239762            70            64       54         50       53          27
# 235155            27            22       29         48       38          17
# 244883            84            86       65         53       73          56
# 247187            67            72       71         54       59          61
#
#         jumping  stamina  strength  long_shots  aggression  interceptions  \
# id
# 41236        68       61        86          82          84             20
# 230168       67       29        79           7          34             23
# 230225       91       76        79          61          86             82
# 183498       77       88        77          86          80             80
# 203890       85       87        73          58          75             80
# ...         ...      ...       ...         ...         ...            ...
# 204322       77       75        64          54          69             41
# 239762       74       66        70          22          62             55
# 235155       43       25        63           9          27             10
# 244883       58       58        49          58          38             15
# 247187       60       57        67          53          67             20
#
#         positioning  vision  penalties  composure  marking  standing_tackle  \
# id
# 41236            85      79         89         90       28               37
# 230168           27      71         14         67       20               17
# 230225           58      50         62         70       77               85
# 183498           82      78         45         78       78               80
# 203890           65      68         52         67       79               81
# ...             ...     ...        ...        ...      ...              ...
# 204322           60      64         63         56       40               20
# 239762           42      39         32         52       53               64
# 235155            5      25         16         47        9               12
# 244883           54      52         50         53       16               18
# 247187           53      49         52         45       23               31
#
#         sliding_tackle  GK_diving  GK_handling  GK_kicking  GK_positioning  \
# id
# 41236               24         13           15          10               9
# 230168              13         79           84          77              83
# 230225              84         18           12          14              11
# 183498              82         13            9           6               7
# 203890              77         15           11          10              10
# ...                ...        ...          ...         ...             ...
# 204322              18         15           11          15              12
# 239762              60         15            7           7              15
# 235155              13         63           57          50              58
# 244883              17         15           14          12               6
# 247187              21          9           14          12              13
#
#         GK_reflexes  attacking     skill  movement     power  mentality  \
# id
# 41236            12  81.400000 80.000000 62.600000 77.400000  74.500000
# 230168           78  11.000000 14.600000 48.000000 40.600000  39.333333
# 230225           18  61.800000 62.400000 68.800000 76.200000  68.000000
# 183498            9  74.200000 71.800000 71.400000 83.000000  73.833333
# 203890           12  65.800000 70.000000 75.000000 75.600000  67.833333
# ...             ...        ...       ...       ...       ...        ...
# age                      0.131832      0.095878
# height_cm               -0.084237      0.291632
# weight_kgs              -0.055431      0.339456
# overall_rating           0.247549     -0.007889
# potential                0.112502     -0.038318
# value_euro               0.157698     -0.049819
# wage_euro                0.161146     -0.041123
# preferred_foot          -0.114828      0.103892
# release_clause_euro      0.153975     -0.038376
# club_rating              0.122683      0.046922
# club_position            0.045535      0.198169
# national_rating          0.047490      0.029786
# national_team_position   0.050414      0.048389
# crossing                 0.435648     -0.673639
# finishing               -0.048626     -0.593360
# heading_accuracy         0.568367     -0.759594
# short_passing            0.548812     -0.752593
# volleys                  0.057009     -0.596935
# dribbling                0.301431     -0.770925
# curve                    0.258690     -0.613031
# freekick_accuracy        0.272856     -0.558845
# long_passing             0.592421     -0.609583
# ball_control             0.422351     -0.811478
# acceleration             0.170350     -0.610290
# sprint_speed             0.187364     -0.618096
# agility                  0.131641     -0.535200
# reactions                0.253461     -0.053833
# balance                  0.164301     -0.508240
# shot_power               0.247839     -0.661367
# jumping                  0.271071     -0.193164
# stamina                  0.583474     -0.718938
# strength                 0.325545     -0.105304
# long_shots               0.163558     -0.616741
# aggression               0.743707     -0.586781
# interceptions            0.944471     -0.489320
# positioning              0.152673     -0.689854
# vision                   0.129915     -0.381363
# penalties                0.090502     -0.623768
# composure                0.361969     -0.407892
# marking                  0.958025     -0.555403
# standing_tackle          0.986409     -0.537063
# sliding_tackle           0.983036     -0.515072
# GK_diving               -0.542164      0.988473
# GK_handling             -0.542398      0.987282
# GK_kicking              -0.541519      0.984753
# GK_positioning          -0.538317      0.987236
# GK_reflexes             -0.543115      0.988764
# attacking                0.352456     -0.797483
# skill                    0.396587     -0.740274
# movement                 0.211633     -0.608974
# power                    0.437220     -0.697268
# mentality                0.593878     -0.739822
# defending                1.000000     -0.548466
# goal_keeping            -0.548466      1.000000

# %%
pd.set_option('display.max_rows', None)
abs(df.corr()) > .65
# Out:
#                           age  height_cm  weight_kgs  overall_rating  \
# age                      True      False       False           False
# height_cm               False       True       False           False
# weight_kgs              False      False        True           False
# overall_rating          False      False       False            True
# potential               False      False       False           False
# value_euro              False      False       False            True
# wage_euro               False      False       False           False
# preferred_foot          False      False       False           False
# release_clause_euro     False      False       False            True
# club_rating             False      False       False           False
# club_position           False      False       False           False
# national_rating         False      False       False           False
# national_team_position  False      False       False           False
# crossing                False      False       False           False
# finishing               False      False       False           False
# heading_accuracy        False      False       False           False
# short_passing           False      False       False           False
# volleys                 False      False       False           False
# dribbling               False      False       False           False
# curve                   False      False       False           False
# freekick_accuracy       False      False       False           False
# long_passing            False      False       False           False
# ball_control            False      False       False           False
# acceleration            False      False       False           False
# sprint_speed            False      False       False           False
# agility                 False      False       False           False
# reactions               False      False       False            True
# balance                 False      False        True           False
# shot_power              False      False       False           False
# jumping                 False      False       False           False
# stamina                 False      False       False           False
# strength                False      False       False           False
# long_shots              False      False       False           False
# aggression              False      False       False           False
# interceptions           False      False       False           False
# positioning             False      False       False           False
# vision                  False      False       False           False
# penalties               False      False       False           False
# composure               False      False       False            True
# marking                 False      False       False           False
# standing_tackle         False      False       False           False
# sliding_tackle          False      False       False           False
# GK_diving               False      False       False           False
# GK_handling             False      False       False           False
# GK_kicking              False      False       False           False
# GK_positioning          False      False       False           False
# GK_reflexes             False      False       False           False
# attacking               False      False       False           False
# skill                   False      False       False           False
# movement                False      False       False           False
# power                   False      False       False           False
# mentality               False      False       False           False
# defending               False      False       False           False
# goal_keeping            False      False       False           False
#
#                         potential  value_euro  wage_euro  preferred_foot  \
# age                         False       False      False           False
# height_cm                   False       False      False           False
# weight_kgs                  False       False      False           False
# overall_rating              False        True      False           False
# potential                    True       False      False           False
# value_euro                  False        True       True           False
# wage_euro                   False        True       True           False
# preferred_foot              False       False      False            True
# release_clause_euro         False        True      False           False
# club_rating                 False       False      False           False
# club_position               False       False      False           False
# national_rating             False       False      False           False
# national_team_position      False       False      False           False
# crossing                    False       False      False           False
# finishing                   False       False      False           False
# heading_accuracy            False       False      False           False
# short_passing               False       False      False           False
# volleys                     False       False      False           False
# dribbling                   False       False      False           False
# curve                       False       False      False           False
# freekick_accuracy           False       False      False           False
# long_passing                False       False      False           False
# ball_control                False       False      False           False
# acceleration                False       False      False           False
# sprint_speed                False       False      False           False
# agility                     False       False      False           False
# reactions                   False       False      False           False
# balance                     False       False      False           False
# shot_power                  False       False      False           False
# jumping                     False       False      False           False
# stamina                     False       False      False           False
# strength                    False       False      False           False
# long_shots                  False       False      False           False
# aggression                  False       False      False           False
# interceptions               False       False      False           False
# positioning                 False       False      False           False
# vision                      False       False      False           False
# penalties                   False       False      False           False
# composure                   False       False      False           False
# marking                     False       False      False           False
# standing_tackle             False       False      False           False
# sliding_tackle              False       False      False           False
# GK_diving                   False       False      False           False
# GK_handling                 False       False      False           False
# GK_kicking                  False       False      False           False
# GK_positioning              False       False      False           False
# GK_reflexes                 False       False      False           False
# attacking                   False       False      False           False
# skill                       False       False      False           False
# movement                    False       False      False           False
# power                       False       False      False           False
# mentality                   False       False      False           False
# defending                   False       False      False           False
# goal_keeping                False       False      False           False
#
#                         release_clause_euro  club_rating  club_position  \
# age                                   False        False          False
# height_cm                             False        False          False
# weight_kgs                            False        False          False
# overall_rating                         True        False          False
# potential                             False        False          False
# value_euro                             True        False          False
# wage_euro                             False        False          False
# preferred_foot                        False        False          False
# release_clause_euro                    True        False          False
# club_rating                           False         True          False
# club_position                         False        False           True
# national_rating                       False        False          False
# national_team_position                False        False          False
# crossing                              False        False          False
# finishing                             False        False          False
# heading_accuracy                      False        False          False
# short_passing                         False        False          False
# volleys                               False        False          False
# dribbling                             False        False          False
# curve                                 False        False          False
# freekick_accuracy                     False        False          False
# long_passing                          False        False          False
# ball_control                          False        False          False
# acceleration                          False        False          False
# sprint_speed                          False        False          False
# agility                               False        False          False
# reactions                             False        False          False
# balance                               False        False          False
# shot_power                            False        False          False
# jumping                               False        False          False
# stamina                               False        False          False
# strength                              False        False          False
# long_shots                            False        False          False
# aggression                            False        False          False
# interceptions                         False        False          False
# positioning                           False        False          False
# vision                                False        False          False
# penalties                             False        False          False
# composure                             False        False          False
# marking                               False        False          False
# standing_tackle                       False        False          False
# sliding_tackle                        False        False          False
# GK_diving                             False        False          False
# GK_handling                           False        False          False
# GK_kicking                            False        False          False
# GK_positioning                        False        False          False
# GK_reflexes                           False        False          False
# attacking                             False        False          False
# skill                                 False        False          False
# movement                              False        False          False
# power                                 False        False          False
# mentality                             False        False          False
# defending                             False        False          False
# goal_keeping                          False        False          False
#
#                         national_rating  national_team_position  crossing  \
# age                               False                   False     False
# height_cm                         False                   False     False
# weight_kgs                        False                   False     False
# overall_rating                    False                   False     False
# potential                         False                   False     False
# value_euro                        False                   False     False
# wage_euro                         False                   False     False
# preferred_foot                    False                   False     False
# release_clause_euro               False                   False     False
# club_rating                       False                   False     False
# club_position                     False                   False     False
# national_rating                    True                    True     False
# national_team_position             True                    True     False
# crossing                          False                   False      True
# finishing                         False                   False     False
# heading_accuracy                  False                   False     False
# short_passing                     False                   False      True
# volleys                           False                   False      True
# dribbling                         False                   False      True
# curve                             False                   False      True
# freekick_accuracy                 False                   False      True
# long_passing                      False                   False      True
# ball_control                      False                   False      True
# acceleration                      False                   False      True
# sprint_speed                      False                   False     False
# agility                           False                   False      True
# reactions                         False                   False     False
# balance                           False                   False     False
# shot_power                        False                   False      True
# jumping                           False                   False     False
# stamina                           False                   False      True
# strength                          False                   False     False
# long_shots                        False                   False      True
# aggression                        False                   False     False
# interceptions                     False                   False     False
# positioning                       False                   False      True
# vision                            False                   False      True
# penalties                         False                   False     False
# composure                         False                   False     False
# marking                           False                   False     False
# standing_tackle                   False                   False     False
# sliding_tackle                    False                   False     False
# GK_diving                         False                   False      True
# GK_handling                       False                   False      True
# GK_kicking                        False                   False      True
# GK_positioning                    False                   False      True
# GK_reflexes                       False                   False      True
# attacking                         False                   False      True
# skill                             False                   False      True
# movement                          False                   False      True
# power                             False                   False      True
# mentality                         False                   False      True
# defending                         False                   False     False
# goal_keeping                      False                   False      True
#
#                         finishing  heading_accuracy  short_passing  volleys  \
# age                         False             False          False    False
# height_cm                   False             False          False    False
# weight_kgs                  False             False          False    False
# overall_rating              False             False          False    False
# potential                   False             False          False    False
# value_euro                  False             False          False    False
# wage_euro                   False             False          False    False
# preferred_foot              False             False          False    False
# release_clause_euro         False             False          False    False
# club_rating                 False             False          False    False
# club_position               False             False          False    False
# national_rating             False             False          False    False
# national_team_position      False             False          False    False
# crossing                    False             False           True     True
# finishing                    True             False          False     True
# heading_accuracy            False              True          False    False
# short_passing               False             False           True     True
# volleys                      True             False           True     True
# dribbling                    True             False           True     True
# curve                        True             False           True     True
# freekick_accuracy            True             False           True     True
# long_passing                False             False           True    False
# ball_control                 True              True           True     True
# acceleration                False             False          False    False
# sprint_speed                False             False          False    False
# agility                     False             False          False    False
# reactions                   False             False          False    False
# balance                     False             False          False    False
# shot_power                   True             False           True     True
# jumping                     False             False          False    False
# stamina                     False             False           True    False
# strength                    False             False          False    False
# long_shots                   True             False           True     True
# aggression                  False              True          False    False
# interceptions               False             False          False    False
# positioning                  True             False           True     True
# vision                       True             False           True     True
# penalties                    True             False           True     True
# composure                   False             False           True    False
# marking                     False             False          False    False
# standing_tackle             False             False          False    False
# sliding_tackle              False             False          False    False
# GK_diving                   False              True           True    False
# GK_handling                 False              True           True    False
# GK_kicking                  False              True           True    False
# GK_positioning              False              True           True    False
# GK_reflexes                 False              True           True    False
# attacking                    True              True           True     True
# skill                        True             False           True     True
# movement                     True             False           True    False
# power                        True              True           True     True
# mentality                    True              True           True     True
# defending                   False             False          False    False
# goal_keeping                False              True           True    False
#
#                         dribbling  curve  freekick_accuracy  long_passing  \
# age                         False  False              False         False
# height_cm                   False  False              False         False
# weight_kgs                  False  False              False         False
# overall_rating              False  False              False         False
# potential                   False  False              False         False
# value_euro                  False  False              False         False
# wage_euro                   False  False              False         False
# preferred_foot              False  False              False         False
# release_clause_euro         False  False              False         False
# club_rating                 False  False              False         False
# club_position               False  False              False         False
# national_rating             False  False              False         False
# national_team_position      False  False              False         False
# crossing                     True   True               True          True
# finishing                    True   True               True         False
# heading_accuracy            False  False              False         False
# short_passing                True   True               True          True
# volleys                      True   True               True         False
# dribbling                    True   True               True          True
# curve                        True   True               True          True
# freekick_accuracy            True   True               True          True
# long_passing                 True   True               True          True
# ball_control                 True   True               True          True
# acceleration                 True  False              False         False
# sprint_speed                 True  False              False         False
# agility                      True   True              False         False
# reactions                   False  False              False         False
# balance                      True  False              False         False
# shot_power                   True   True               True          True
# jumping                     False  False              False         False
# stamina                      True  False              False         False
# strength                    False  False              False         False
# long_shots                   True   True               True          True
# aggression                  False  False              False         False
# interceptions               False  False              False         False
# positioning                  True   True               True         False
# vision                       True   True               True          True
# penalties                    True   True               True         False
# composure                   False  False              False         False
# marking                     False  False              False         False
# standing_tackle             False  False              False         False
# sliding_tackle              False  False              False         False
# GK_diving                    True  False              False         False
# GK_handling                  True  False              False         False
# GK_kicking                   True  False              False         False
# GK_positioning               True  False              False         False
# GK_reflexes                  True  False              False         False
# attacking                    True   True               True          True
# skill                        True   True               True          True
# movement                     True   True              False         False
# power                        True   True               True          True
# mentality                    True   True               True          True
# defending                   False  False              False         False
# goal_keeping                 True  False              False         False
#
#                         ball_control  acceleration  sprint_speed  agility  \
# age                            False         False         False    False
# height_cm                      False         False         False    False
# weight_kgs                     False         False         False    False
# overall_rating                 False         False         False    False
# potential                      False         False         False    False
# value_euro                     False         False         False    False
# wage_euro                      False         False         False    False
# preferred_foot                 False         False         False    False
# release_clause_euro            False         False         False    False
# club_rating                    False         False         False    False
# club_position                  False         False         False    False
# national_rating                False         False         False    False
# national_team_position         False         False         False    False
# crossing                        True          True         False     True
# finishing                       True         False         False    False
# heading_accuracy                True         False         False    False
# short_passing                   True         False         False    False
# volleys                         True         False         False    False
# dribbling                       True          True          True     True
# curve                           True         False         False     True
# freekick_accuracy               True         False         False    False
# long_passing                    True         False         False    False
# ball_control                    True          True          True     True
# acceleration                    True          True          True     True
# sprint_speed                    True          True          True     True
# agility                         True          True          True     True
# reactions                      False         False         False    False
# balance                        False          True         False     True
# shot_power                      True         False         False    False
# jumping                        False         False         False    False
# stamina                         True         False         False    False
# strength                       False         False         False    False
# long_shots                      True         False         False    False
# aggression                     False         False         False    False
# interceptions                  False         False         False    False
# positioning                     True          True          True     True
# vision                          True         False         False    False
# penalties                       True         False         False    False
# composure                       True         False         False    False
# marking                        False         False         False    False
# standing_tackle                False         False         False    False
# sliding_tackle                 False         False         False    False
# GK_diving                       True         False         False    False
# GK_handling                     True         False         False    False
# GK_kicking                      True         False         False    False
# GK_positioning                  True         False         False    False
# GK_reflexes                     True         False         False    False
# attacking                       True         False         False     True
# skill                           True         False         False     True
# movement                        True          True          True     True
# power                           True         False         False    False
# mentality                       True         False         False    False
# defending                      False         False         False    False
# goal_keeping                    True         False         False    False
#
#                         reactions  balance  shot_power  jumping  stamina  \
# age                         False    False       False    False    False
# height_cm                   False    False       False    False    False
# weight_kgs                  False     True       False    False    False
# overall_rating               True    False       False    False    False
# potential                   False    False       False    False    False
# value_euro                  False    False       False    False    False
# wage_euro                   False    False       False    False    False
# preferred_foot              False    False       False    False    False
# release_clause_euro         False    False       False    False    False
# club_rating                 False    False       False    False    False
# club_position               False    False       False    False    False
# national_rating             False    False       False    False    False
# national_team_position      False    False       False    False    False
# crossing                    False    False        True    False     True
# finishing                   False    False        True    False    False
# heading_accuracy            False    False       False    False    False
# short_passing               False    False        True    False     True
# volleys                     False    False        True    False    False
# dribbling                   False     True        True    False     True
# curve                       False    False        True    False    False
# freekick_accuracy           False    False        True    False    False
# long_passing                False    False        True    False    False
# ball_control                False    False        True    False     True
# acceleration                False     True       False    False    False
# sprint_speed                False    False       False    False    False
# agility                     False     True       False    False    False
# reactions                    True    False       False    False    False
# balance                     False     True       False    False    False
# shot_power                  False    False        True    False    False
# jumping                     False    False       False     True    False
# stamina                     False    False       False    False     True
# strength                    False    False       False    False    False
# long_shots                  False    False        True    False    False
# aggression                  False    False       False    False    False
# interceptions               False    False       False    False    False
# positioning                 False    False        True    False    False
# vision                      False    False        True    False    False
# penalties                   False    False        True    False    False
# composure                   False    False       False    False    False
# marking                     False    False       False    False    False
# standing_tackle             False    False       False    False    False
# sliding_tackle              False    False       False    False    False
# GK_diving                   False    False        True    False     True
# GK_handling                 False    False        True    False     True
# GK_kicking                  False    False        True    False     True
# GK_positioning              False    False        True    False     True
# GK_reflexes                 False    False        True    False     True
# attacking                   False    False        True    False     True
# skill                       False    False        True    False     True
# movement                    False     True       False    False    False
# power                       False    False        True    False     True
# mentality                   False    False        True    False     True
# defending                   False    False       False    False    False
# goal_keeping                False    False        True    False     True
#
#                         strength  long_shots  aggression  interceptions  \
# age                        False       False       False          False
# height_cm                  False       False       False          False
# weight_kgs                 False       False       False          False
# overall_rating             False       False       False          False
# potential                  False       False       False          False
# value_euro                 False       False       False          False
# wage_euro                  False       False       False          False
# preferred_foot             False       False       False          False
# release_clause_euro        False       False       False          False
# club_rating                False       False       False          False
# club_position              False       False       False          False
# national_rating            False       False       False          False
# national_team_position     False       False       False          False
# crossing                   False        True       False          False
# finishing                  False        True       False          False
# heading_accuracy           False       False        True          False
# short_passing              False        True       False          False
# volleys                    False        True       False          False
# dribbling                  False        True       False          False
# curve                      False        True       False          False
# freekick_accuracy          False        True       False          False
# long_passing               False        True       False          False
# ball_control               False        True       False          False
# acceleration               False       False       False          False
# sprint_speed               False       False       False          False
# agility                    False       False       False          False
# reactions                  False       False       False          False
# balance                    False       False       False          False
# shot_power                 False        True       False          False
# jumping                    False       False       False          False
# stamina                    False       False       False          False
# strength                    True       False       False          False
# long_shots                 False        True       False          False
# aggression                 False       False        True           True
# interceptions              False       False        True           True
# positioning                False        True       False          False
# vision                     False        True       False          False
# penalties                  False        True       False          False
# composure                  False       False       False          False
# marking                    False       False        True           True
# standing_tackle            False       False        True           True
# sliding_tackle             False       False        True           True
# GK_diving                  False       False       False          False
# GK_handling                False       False       False          False
# GK_kicking                 False       False       False          False
# GK_positioning             False       False       False          False
# GK_reflexes                False       False       False          False
# attacking                  False        True       False          False
# skill                      False        True       False          False
# movement                   False        True       False          False
# power                      False        True        True          False
# mentality                  False        True        True          False
# defending                  False       False        True           True
# goal_keeping               False       False       False          False
#
#                         positioning  vision  penalties  composure  marking  \
# age                           False   False      False      False    False
# height_cm                     False   False      False      False    False
# weight_kgs                    False   False      False      False    False
# overall_rating                False   False      False       True    False
# potential                     False   False      False      False    False
# value_euro                    False   False      False      False    False
# wage_euro                     False   False      False      False    False
# preferred_foot                False   False      False      False    False
# release_clause_euro           False   False      False      False    False
# club_rating                   False   False      False      False    False
# club_position                 False   False      False      False    False
# national_rating               False   False      False      False    False
# national_team_position        False   False      False      False    False
# crossing                       True    True      False      False    False
# finishing                      True    True       True      False    False
# heading_accuracy              False   False      False      False    False
# short_passing                  True    True       True       True    False
# volleys                        True    True       True      False    False
# dribbling                      True    True       True      False    False
# curve                          True    True       True      False    False
# freekick_accuracy              True    True       True      False    False
# long_passing                  False    True      False      False    False
# ball_control                   True    True       True       True    False
# acceleration                   True   False      False      False    False
# sprint_speed                   True   False      False      False    False
# agility                        True   False      False      False    False
# reactions                     False   False      False      False    False
# balance                       False   False      False      False    False
# shot_power                     True    True       True      False    False
# jumping                       False   False      False      False    False
# stamina                       False   False      False      False    False
# strength                      False   False      False      False    False
# long_shots                     True    True       True      False    False
# aggression                    False   False      False      False     True
# interceptions                 False   False      False      False     True
# positioning                    True    True       True      False    False
# vision                         True    True      False      False    False
# penalties                      True   False       True      False    False
# composure                     False   False      False       True    False
# marking                       False   False      False      False     True
# standing_tackle               False   False      False      False     True
# sliding_tackle                False   False      False      False     True
# GK_diving                      True   False      False      False    False
# GK_handling                    True   False      False      False    False
# GK_kicking                     True   False      False      False    False
# GK_positioning                 True   False      False      False    False
# GK_reflexes                    True   False      False      False    False
# attacking                      True    True       True       True    False
# skill                          True    True       True       True    False
# movement                       True   False      False      False    False
# power                          True   False       True       True    False
# mentality                      True    True       True       True    False
# defending                     False   False      False      False     True
# goal_keeping                   True   False      False      False    False
#
#                         standing_tackle  sliding_tackle  GK_diving  \
# age                               False           False      False
# height_cm                         False           False      False
# weight_kgs                        False           False      False
# overall_rating                    False           False      False
# potential                         False           False      False
# value_euro                        False           False      False
# wage_euro                         False           False      False
# preferred_foot                    False           False      False
# release_clause_euro               False           False      False
# club_rating                       False           False      False
# club_position                     False           False      False
# national_rating                   False           False      False
# national_team_position            False           False      False
# crossing                          False           False       True
# finishing                         False           False      False
# heading_accuracy                  False           False       True
# short_passing                     False           False       True
# volleys                           False           False      False
# dribbling                         False           False       True
# curve                             False           False      False
# freekick_accuracy                 False           False      False
# long_passing                      False           False      False
# ball_control                      False           False       True
# acceleration                      False           False      False
# sprint_speed                      False           False      False
# agility                           False           False      False
# reactions                         False           False      False
# balance                           False           False      False
# shot_power                        False           False       True
# jumping                           False           False      False
# stamina                           False           False       True
# strength                          False           False      False
# long_shots                        False           False      False
# aggression                         True            True      False
# interceptions                      True            True      False
# positioning                       False           False       True
# vision                            False           False      False
# penalties                         False           False      False
# composure                         False           False      False
# marking                            True            True      False
# standing_tackle                    True            True      False
# sliding_tackle                     True            True      False
# GK_diving                         False           False       True
# GK_handling                       False           False       True
# GK_kicking                        False           False       True
# GK_positioning                    False           False       True
# GK_reflexes                       False           False       True
# attacking                         False           False       True
# skill                             False           False       True
# movement                          False           False      False
# power                             False           False       True
# mentality                         False           False       True
# defending                          True            True      False
# goal_keeping                      False           False       True
#
#                         GK_handling  GK_kicking  GK_positioning  GK_reflexes  \
# age                           False       False           False        False
# height_cm                     False       False           False        False
# weight_kgs                    False       False           False        False
# overall_rating                False       False           False        False
# potential                     False       False           False        False
# value_euro                    False       False           False        False
# wage_euro                     False       False           False        False
# preferred_foot                False       False           False        False
# release_clause_euro           False       False           False        False
# club_rating                   False       False           False        False
# club_position                 False       False           False        False
# national_rating               False       False           False        False
# national_team_position        False       False           False        False
# crossing                       True        True            True         True
# finishing                     False       False           False        False
# heading_accuracy               True        True            True         True
# short_passing                  True        True            True         True
# volleys                       False       False           False        False
# dribbling                      True        True            True         True
# curve                         False       False           False        False
# freekick_accuracy             False       False           False        False
# long_passing                  False       False           False        False
# ball_control                   True        True            True         True
# acceleration                  False       False           False        False
# sprint_speed                  False       False           False        False
# agility                       False       False           False        False
# reactions                     False       False           False        False
# balance                       False       False           False        False
# shot_power                     True        True            True         True
# jumping                       False       False           False        False
# stamina                        True        True            True         True
# strength                      False       False           False        False
# long_shots                    False       False           False        False
# aggression                    False       False           False        False
# interceptions                 False       False           False        False
# positioning                    True        True            True         True
# vision                        False       False           False        False
# penalties                     False       False           False        False
# composure                     False       False           False        False
# marking                       False       False           False        False
# standing_tackle               False       False           False        False
# sliding_tackle                False       False           False        False
# GK_diving                      True        True            True         True
# GK_handling                    True        True            True         True
# GK_kicking                     True        True            True         True
# GK_positioning                 True        True            True         True
# GK_reflexes                    True        True            True         True
# attacking                      True        True            True         True
# skill                          True        True            True         True
# movement                      False       False           False        False
# power                          True        True            True         True
# mentality                      True        True            True         True
# defending                     False       False           False        False
# goal_keeping                   True        True            True         True
#
#                         attacking  skill  movement  power  mentality  \
# age                         False  False     False  False      False
# height_cm                   False  False     False  False      False
# weight_kgs                  False  False     False  False      False
# overall_rating              False  False     False  False      False
# potential                   False  False     False  False      False
# value_euro                  False  False     False  False      False
# wage_euro                   False  False     False  False      False
# preferred_foot              False  False     False  False      False
# release_clause_euro         False  False     False  False      False
# club_rating                 False  False     False  False      False
# club_position               False  False     False  False      False
# national_rating             False  False     False  False      False
# national_team_position      False  False     False  False      False
# crossing                     True   True      True   True       True
# finishing                    True   True      True   True       True
# heading_accuracy             True  False     False   True       True
# short_passing                True   True      True   True       True
# volleys                      True   True     False   True       True
# dribbling                    True   True      True   True       True
# curve                        True   True      True   True       True
# freekick_accuracy            True   True     False   True       True
# long_passing                 True   True     False   True       True
# ball_control                 True   True      True   True       True
# acceleration                False  False      True  False      False
# sprint_speed                False  False      True  False      False
# agility                      True   True      True  False      False
# reactions                   False  False     False  False      False
# balance                     False  False      True  False      False
# shot_power                   True   True     False   True       True
# jumping                     False  False     False  False      False
# stamina                      True   True     False   True       True
# strength                    False  False     False  False      False
# long_shots                   True   True      True   True       True
# aggression                  False  False     False   True       True
# interceptions               False  False     False  False      False
# positioning                  True   True      True   True       True
# vision                       True   True     False  False       True
# penalties                    True   True     False   True       True
# composure                    True   True     False   True       True
# marking                     False  False     False  False      False
# standing_tackle             False  False     False  False      False
# sliding_tackle              False  False     False  False      False
# GK_diving                    True   True     False   True       True
# GK_handling                  True   True     False   True       True
# GK_kicking                   True   True     False   True       True
# GK_positioning               True   True     False   True       True
# GK_reflexes                  True   True     False   True       True
# attacking                    True   True      True   True       True
# skill                        True   True      True   True       True
# movement                     True   True      True  False      False
# power                        True   True     False   True       True
# mentality                    True   True     False   True       True
# defending                   False  False     False  False      False
# goal_keeping                 True   True     False   True       True
#
#                         defending  goal_keeping
# age                         False         False
# height_cm                   False         False
# weight_kgs                  False         False
# overall_rating              False         False
# potential                   False         False
# value_euro                  False         False
# wage_euro                   False         False
# preferred_foot              False         False
# release_clause_euro         False         False
# club_rating                 False         False
# club_position               False         False
# national_rating             False         False
# national_team_position      False         False
# crossing                    False          True
# finishing                   False         False
# heading_accuracy            False          True
# short_passing               False          True
# volleys                     False         False
# dribbling                   False          True
# curve                       False         False
# freekick_accuracy           False         False
# long_passing                False         False
# ball_control                False          True
# acceleration                False         False
# sprint_speed                False         False
# agility                     False         False
# reactions                   False         False
# balance                     False         False
# shot_power                  False          True
# jumping                     False         False
# stamina                     False          True
# strength                    False         False
# long_shots                  False         False
# aggression                   True         False
# interceptions                True         False
# positioning                 False          True
# vision                      False         False
# penalties                   False         False
# composure                   False         False
# marking                      True         False
# standing_tackle              True         False
# sliding_tackle               True         False
# GK_diving                   False          True
# GK_handling                 False          True
# GK_kicking                  False          True
# GK_positioning              False          True
# GK_reflexes                 False          True
# attacking                   False          True
# skill                       False          True
# movement                    False         False
# power                       False          True
# mentality                   False          True
# defending                    True         False
# goal_keeping                False          True

# %% [markdown]
# # <span id="12"></span> Standardization
# #### [Return Contents](#0)

# %% [markdown]
# Although most of our data of interest was already in the same scale (1-99), we decided to apply a standard scaler so we could see if it had any impact on the models.

# %%
df.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kgs', 'nationality',
#        'overall_rating', 'potential', 'value_euro', 'wage_euro',
#        'preferred_foot', 'release_clause_euro', 'club_team', 'club_rating',
#        'club_position', 'national_team', 'national_rating',
#        'national_team_position', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
#        'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
#        'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
#        'power', 'mentality', 'defending', 'goal_keeping'],
#       dtype='object')

# %%
all_features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'club_rating', 'club_position', 'national_rating',
       'national_team_position', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
subset_scaled = []
for var in all_features:
    new_col = var +"_scaled"
    df[new_col] = scaler.fit_transform(df[[var]])
    subset_scaled.append(new_col)

# %%
df

# %% [markdown]
# # <span id="13"></span> Train & Test Split
# #### [Return Contents](#0)

# %%
train_data,test_data = train_test_split(df,train_size = 0.8,random_state=3)

# %% [markdown]
# # <span id="14"></span> Linear Regression Models
# #### [Return Contents](#0)

# %%
def adjustedR2(r2,n,k):
    return r2-(k-1)/(n-k)*(1-r2)

# %% [markdown]
# # MLR_1: All Featues, Not Processed

# %%
features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_1','all features, not processed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: -19944183.636227656
# Coefficients: [-1.97110546e+05  1.64677630e+03  8.50014835e+03  3.80656155e+05
#   1.06909279e+04  9.98114389e+04 -1.38268645e+15 -1.38268645e+15
#  -1.38268645e+15 -1.38268645e+15 -1.38268645e+15  4.36413049e+14
#   4.36413049e+14  4.36413049e+14  4.36413049e+14  4.36413049e+14
#   1.37142420e+15  1.37142420e+15  1.37142420e+15  1.37142420e+15
#   1.37142420e+15  7.81033062e+14  7.81033062e+14  7.81033062e+14
#   7.81033062e+14  7.81033062e+14 -7.35118644e+14 -7.35118644e+14
#  -7.35118644e+14 -7.35118644e+14 -7.35118644e+14 -7.35118644e+14
#  -5.43877521e+15 -5.43877521e+15 -5.43877521e+15  4.48537817e+14
#   4.48537817e+14  4.48537817e+14  4.48537817e+14  4.48537817e+14
#   6.91343226e+15 -2.18206524e+15 -6.85712098e+15 -3.90516531e+15
#   4.41071186e+15  1.63163256e+16 -2.24268908e+15]
#    Model                      Details  Root Mean Squared Error (RMSE)  \
# 0  MLR_1  all features, not processed                  1562209.347000
#
#    R-squared (training)  Adjusted R-squared (training)  R-squared (test)  \
# 0              0.662000                       0.661000          0.660000
#
#    Adjusted R-squared (test)  5-Fold Cross Validation
# 0                   0.656000                 0.659000

# %% [markdown]
# # MLR_2: All Features, Preprocessed

# %%
pd.set_option('display.max_columns', None)
list(df.columns)
# Out:
# ['name',
#  'age',
#  'height_cm',
#  'weight_kgs',
#  'nationality',
#  'overall_rating',
#  'potential',
#  'value_euro',
#  'wage_euro',
#  'preferred_foot',
#  'release_clause_euro',
#  'club_team',
#  'club_rating',
#  'club_position',
#  'national_team',
#  'national_rating',
#  'national_team_position',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'freekick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'GK_diving',
#  'GK_handling',
#  'GK_kicking',
#  'GK_positioning',
#  'GK_reflexes',
#  'attacking',
#  'skill',
#  'movement',
#  'power',
#  'mentality',
#  'defending',
#  'goal_keeping',
#  'age_scaled',
#  'height_cm_scaled',
#  'weight_kgs_scaled',
#  'overall_rating_scaled',
#  'potential_scaled',
#  'preferred_foot_scaled',
#  'club_rating_scaled',
#  'club_position_scaled',
#  'national_rating_scaled',
#  'national_team_position_scaled',
#  'crossing_scaled',
#  'finishing_scaled',
#  'heading_accuracy_scaled',
#  'short_passing_scaled',
#  'volleys_scaled',
#  'dribbling_scaled',
#  'curve_scaled',
#  'freekick_accuracy_scaled',
#  'long_passing_scaled',
#  'ball_control_scaled',
#  'acceleration_scaled',
#  'sprint_speed_scaled',
#  'agility_scaled',
#  'reactions_scaled',
#  'balance_scaled',
#  'shot_power_scaled',
#  'jumping_scaled',
#  'stamina_scaled',
#  'strength_scaled',
#  'long_shots_scaled',
#  'aggression_scaled',
#  'interceptions_scaled',
#  'positioning_scaled',
#  'vision_scaled',
#  'penalties_scaled',
#  'composure_scaled',
#  'marking_scaled',
#  'standing_tackle_scaled',
#  'sliding_tackle_scaled',
#  'GK_diving_scaled',
#  'GK_handling_scaled',
#  'GK_kicking_scaled',
#  'GK_positioning_scaled',
#  'GK_reflexes_scaled',
#  'attacking_scaled',
#  'skill_scaled',
#  'movement_scaled',
#  'power_scaled',
#  'mentality_scaled',
#  'defending_scaled',
#  'goal_keeping_scaled']

# %%
features = ['age_scaled',
 'height_cm_scaled',
 'weight_kgs_scaled',
 'overall_rating_scaled',
 'potential_scaled',
 'preferred_foot_scaled',
 'crossing_scaled',
 'finishing_scaled',
 'heading_accuracy_scaled',
 'short_passing_scaled',
 'volleys_scaled',
 'dribbling_scaled',
 'curve_scaled',
 'freekick_accuracy_scaled',
 'long_passing_scaled',
 'ball_control_scaled',
 'acceleration_scaled',
 'sprint_speed_scaled',
 'agility_scaled',
 'reactions_scaled',
 'balance_scaled',
 'shot_power_scaled',
 'jumping_scaled',
 'stamina_scaled',
 'strength_scaled',
 'long_shots_scaled',
 'aggression_scaled',
 'interceptions_scaled',
 'positioning_scaled',
 'vision_scaled',
 'penalties_scaled',
 'composure_scaled',
 'marking_scaled',
 'standing_tackle_scaled',
 'sliding_tackle_scaled',
 'GK_diving_scaled',
 'GK_handling_scaled',
 'GK_kicking_scaled',
 'GK_positioning_scaled',
 'GK_reflexes_scaled',
 'attacking_scaled',
 'skill_scaled',
 'movement_scaled',
 'power_scaled',
 'mentality_scaled',
 'defending_scaled',
 'goal_keeping_scaled']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_2','all features, preprocessed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: 1825735.0825223431
# Coefficients: [-9.08933276e+05  2.33351470e+04  6.01425209e+04  2.32771268e+06
#   5.97094018e+04  4.23186933e+04  4.23985585e+16  4.51117397e+16
#   4.02087409e+16  3.34403610e+16  4.06578945e+16  4.72445016e+15
#   4.61795311e+15  4.39733972e+15  3.82503073e+15  4.12359565e+15
#   5.79993410e+16  5.68872713e+16  5.74056924e+16  3.31666251e+16
#   5.54842990e+16 -3.50967288e+16 -2.42124245e+16 -3.22311493e+16
#  -2.59527057e+16 -3.93652875e+16 -1.16489337e+17 -1.39534683e+17
#  -1.29824254e+17 -9.28248937e+16 -1.04538504e+17 -7.44013792e+16
#  -1.19662709e+17 -1.29710299e+17 -1.27554426e+17 -4.55453549e+16
#  -4.34507137e+16 -4.24435908e+16 -4.38088089e+16 -4.62917174e+16
#  -1.69669162e+17 -1.97338646e+16 -2.15553779e+17  1.11968551e+17
#   4.82746241e+17  3.67977795e+17  2.18736113e+17]
#    Model                      Details  Root Mean Squared Error (RMSE)  \
# 0  MLR_1  all features, not processed                  1562209.347000
# 1  MLR_2   all features, preprocessed                  1562208.121000
#
#    R-squared (training)  Adjusted R-squared (training)  R-squared (test)  \
# 0              0.662000                       0.661000          0.660000
# 1              0.662000                       0.661000          0.660000
#
#    Adjusted R-squared (test)  5-Fold Cross Validation
# 0                   0.656000                 0.659000
# 1                   0.656000                 0.659000

# %% [markdown]
# # MLR_3: Basic & Individual, Not Processed

# %%
features = ['age', 'overall_rating', 'potential', 'preferred_foot', 'short_passing', 'long_passing', 'ball_control', 'reactions', 'shot_power', 'vision', 'composure']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_3','basic & individual, not processed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: -20022612.651279103
# Coefficients: [-186927.2594606   354820.84028156   19425.06620355  113151.28386125
#    -4138.97235888   -3531.21532289   -6010.68472239   16131.37561086
#     6086.57334383   12200.56445984    7828.99993431]
#    Model                            Details  Root Mean Squared Error (RMSE)  \
# 0  MLR_1        all features, not processed                  1562209.347000
# 1  MLR_2         all features, preprocessed                  1562208.121000
# 2  MLR_3  basic & individual, not processed                  1573193.418000
#
#    R-squared (training)  Adjusted R-squared (training)  R-squared (test)  \
# 0              0.662000                       0.661000          0.660000
# 1              0.662000                       0.661000          0.660000
# 2              0.657000                       0.657000          0.656000
#
#    Adjusted R-squared (test)  5-Fold Cross Validation
# 0                   0.656000                 0.659000
# 1                   0.656000                 0.659000
# 2                   0.654000                 0.656000

# %% [markdown]
# # MLR_4: Basic & Categories, Not Processed

# %%
features = ['age','overall_rating','potential','preferred_foot','attacking',
 'skill','movement','power','mentality','defending','goal_keeping']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_4','basic & categories, not processed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: -19604008.35422471
# Coefficients: [-191042.00477356  375207.5017646    15054.55343662  113770.50215232
#    12084.84830906   -4652.97296885   -8886.28078812  -15148.98101097
#    32773.75561496   -8019.06616708    4807.54097032]
#    Model                            Details  Root Mean Squared Error (RMSE)  \
# 0  MLR_1        all features, not processed                  1562209.347000
# 1  MLR_2         all features, preprocessed                  1562208.121000
# 2  MLR_3  basic & individual, not processed                  1573193.418000
# 3  MLR_4  basic & categories, not processed                  1575590.586000
#
#    R-squared (training)  Adjusted R-squared (training)  R-squared (test)  \
# 0              0.662000                       0.661000          0.660000
# 1              0.662000                       0.661000          0.660000
# 2              0.657000                       0.657000          0.656000
# 3              0.658000                       0.657000          0.654000
#
#    Adjusted R-squared (test)  5-Fold Cross Validation
# 0                   0.656000                 0.659000
# 1                   0.656000                 0.659000
# 2                   0.654000                 0.656000
# 3                   0.653000                 0.656000

# %% [markdown]
# # MLR_5: Basic, Individual & Category, Not Processed

# %%
features = ['age_scaled','overall_rating_scaled','potential_scaled','preferred_foot_scaled','attacking_scaled',]

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_5','basic, individual & categories, not processed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: 1825129.5547354294
# Coefficients: [-802365.43367922 2281990.93005335  134688.07209041   62174.60529888
#   102794.63021289]
#    Model                                        Details  \
# 0  MLR_1                    all features, not processed
# 1  MLR_2                     all features, preprocessed
# 2  MLR_3              basic & individual, not processed
# 3  MLR_4              basic & categories, not processed
# 4  MLR_5  basic, individual & categories, not processed
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                  1562209.347000              0.662000
# 1                  1562208.121000              0.662000
# 2                  1573193.418000              0.657000
# 3                  1575590.586000              0.658000
# 4                  1580000.765000              0.654000
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 0                       0.661000          0.660000                   0.656000
# 1                       0.661000          0.660000                   0.656000
# 2                       0.657000          0.656000                   0.654000
# 3                       0.657000          0.654000                   0.653000
# 4                       0.654000          0.653000                   0.652000
#
#    5-Fold Cross Validation
# 0                 0.659000
# 1                 0.659000
# 2                 0.656000
# 3                 0.656000
# 4                 0.653000

# %% [markdown]
# # MLR_6: Baisc & Individual, Processed

# %%
feature = ['age_scaled','overall_rating_scaled','potential_scaled','preferred_foot_scaled','short_passing_scaled', 'long_passing_scaled','ball_control_scaled','reactions_scaled','shot_power_scaled','vision_scaled','composure_scaled']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_6','basic & individual, preprocessed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: 1825129.5547354294
# Coefficients: [-802365.43367922 2281990.93005335  134688.07209041   62174.60529888
#   102794.63021289]
#    Model                                        Details  \
# 0  MLR_1                    all features, not processed
# 1  MLR_2                     all features, preprocessed
# 2  MLR_3              basic & individual, not processed
# 3  MLR_4              basic & categories, not processed
# 4  MLR_5  basic, individual & categories, not processed
# 5  MLR_6               basic & individual, preprocessed
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                  1562209.347000              0.662000
# 1                  1562208.121000              0.662000
# 2                  1573193.418000              0.657000
# 3                  1575590.586000              0.658000
# 4                  1580000.765000              0.654000
# 5                  1580000.765000              0.654000
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 0                       0.661000          0.660000                   0.656000
# 1                       0.661000          0.660000                   0.656000
# 2                       0.657000          0.656000                   0.654000
# 3                       0.657000          0.654000                   0.653000
# 4                       0.654000          0.653000                   0.652000
# 5                       0.654000          0.653000                   0.652000
#
#    5-Fold Cross Validation
# 0                 0.659000
# 1                 0.659000
# 2                 0.656000
# 3                 0.656000
# 4                 0.653000
# 5                 0.653000

# %% [markdown]
# # MLR_7: Basic & Categories, Preprocessed

# %%
features = ['age_scaled','overall_rating_scaled','potential_scaled','preferred_foot_scaled','attacking_scaled','skill_scaled','movement_scaled','power_scaled','mentality_scaled','defending_scaled','goal_keeping_scaled']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_7','basic & categories, preprocessed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: 1824548.8870873756
# Coefficients: [-881480.89365948 2294858.42966999   83474.67195277   48235.19741673
#   173858.22227434  -71530.08258437  -96498.62066579 -162569.32329367
#   387744.92205534 -162496.55092196   80846.36491034]
#    Model                                        Details  \
# 0  MLR_1                    all features, not processed
# 1  MLR_2                     all features, preprocessed
# 2  MLR_3              basic & individual, not processed
# 3  MLR_4              basic & categories, not processed
# 6  MLR_7               basic & categories, preprocessed
# 4  MLR_5  basic, individual & categories, not processed
# 5  MLR_6               basic & individual, preprocessed
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                  1562209.347000              0.662000
# 1                  1562208.121000              0.662000
# 2                  1573193.418000              0.657000
# 3                  1575590.586000              0.658000
# 6                  1575590.586000              0.658000
# 4                  1580000.765000              0.654000
# 5                  1580000.765000              0.654000
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 0                       0.661000          0.660000                   0.656000
# 1                       0.661000          0.660000                   0.656000
# 2                       0.657000          0.656000                   0.654000
# 3                       0.657000          0.654000                   0.653000
# 6                       0.657000          0.654000                   0.653000
# 4                       0.654000          0.653000                   0.652000
# 5                       0.654000          0.653000                   0.652000
#
#    5-Fold Cross Validation
# 0                 0.659000
# 1                 0.659000
# 2                 0.656000
# 3                 0.656000
# 6                 0.656000
# 4                 0.653000
# 5                 0.653000

# %% [markdown]
# # MLR_8: Basic, Individual & Categories, PreProcessed

# %%
features = ['age_scaled','overall_rating_scaled','potential_scaled','preferred_foot_scaled','attacking_scaled', 'skill_scaled','movement_scaled','power_scaled','mentality_scaled','defending_scaled','goal_keeping_scaled','short_passing_scaled','long_passing_scaled','ball_control_scaled','reactions_scaled','shot_power_scaled','vision_scaled','composure_scaled']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))

pred = complex_model_2.predict(test_data[features])
rmsecm = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred)),'.3f'))
rtrcm = float(format(complex_model_2.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm = float(format(adjustedR2(complex_model_2.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm = float(format(complex_model_2.score(test_data[features],test_data['value_euro']),'.3f'))
artecm = float(format(adjustedR2(complex_model_2.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv = float(format(cross_val_score(linear_model.LinearRegression(),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['MLR_8','basic, individual & categories, preprocessed',rmsecm,rtrcm,artrcm,rtecm,artecm,cv]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False,)
# Out:
# Intercept: 1825211.011671562
# Coefficients: [-913476.79783775 2276159.45104787   71764.64039971   52151.42227938
#   244939.86383181   93915.12590284 -105433.3190333  -199876.68170265
#   215632.25175204  -92879.75355769  -93372.92035454 -143939.61168135
#   -23683.78832948 -267857.15694678  149336.9493594    68377.74305305
#    94688.75571407   38508.16308412]
#    Model                                        Details  \
# 0  MLR_1                    all features, not processed
# 1  MLR_2                     all features, preprocessed
# 7  MLR_8   basic, individual & categories, preprocessed
# 2  MLR_3              basic & individual, not processed
# 3  MLR_4              basic & categories, not processed
# 6  MLR_7               basic & categories, preprocessed
# 4  MLR_5  basic, individual & categories, not processed
# 5  MLR_6               basic & individual, preprocessed
#
#    Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                  1562209.347000              0.662000
# 1                  1562208.121000              0.662000
# 7                  1567862.487000              0.660000
# 2                  1573193.418000              0.657000
# 3                  1575590.586000              0.658000
# 6                  1575590.586000              0.658000
# 4                  1580000.765000              0.654000
# 5                  1580000.765000              0.654000
#
#    Adjusted R-squared (training)  R-squared (test)  Adjusted R-squared (test)  \
# 0                       0.661000          0.660000                   0.656000
# 1                       0.661000          0.660000                   0.656000
# 7                       0.659000          0.658000                   0.656000
# 2                       0.657000          0.656000                   0.654000
# 3                       0.657000          0.654000                   0.653000
# 6                       0.657000          0.654000                   0.653000
# 4                       0.654000          0.653000                   0.652000
# 5                       0.654000          0.653000                   0.652000
#
#    5-Fold Cross Validation
# 0                 0.659000
# 1                 0.659000
# 7                 0.658000
# 2                 0.656000
# 3                 0.656000
# 6                 0.656000
# 4                 0.653000
# 5                 0.653000

# %% [markdown]
# # <span id="15"></span> Ridge Regression: All Features, Not Processed
# #### [Return Contents](#0)

# %%
features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']

# %%
complex_model_R = linear_model.Ridge(alpha=1)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred1 = complex_model_R.predict(test_data[features])
rmsecm1 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred1)),'.3f'))
rtrcm1 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm1 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm1 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm1 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv1 = float(format(cross_val_score(linear_model.Ridge(alpha=1),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=100)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred2 = complex_model_R.predict(test_data[features])
rmsecm2 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred2)),'.3f'))
rtrcm2 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm2 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm2 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm2 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv2 = float(format(cross_val_score(linear_model.Ridge(alpha=100),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=1000)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred3 = complex_model_R.predict(test_data[features])
rmsecm3 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred3)),'.3f'))
rtrcm3 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm3 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm3 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm3 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv3 = float(format(cross_val_score(linear_model.Ridge(alpha=1000),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['Ridge Regression','alpha=1, all features, not processed',rmsecm1,rtrcm1,artrcm1,rtecm1,artecm1,cv1]
evaluate.loc[r+1] = ['Ridge Regression','alpha=100, all features, not processed',rmsecm2,rtrcm2,artrcm2,rtecm2,artecm2,cv2]
evaluate.loc[r+2] = ['Ridge Regression','alpha=1000, all features, not processed',rmsecm3,rtrcm3,artrcm3,rtecm3,artecm3,cv3]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False)
# Out:
#                Model                                        Details  \
# 0              MLR_1                    all features, not processed
# 1              MLR_2                     all features, preprocessed
# 8   Ridge Regression           alpha=1, all features, not processed
# 9   Ridge Regression         alpha=100, all features, not processed
# 10  Ridge Regression        alpha=1000, all features, not processed
# 7              MLR_8   basic, individual & categories, preprocessed
# 2              MLR_3              basic & individual, not processed
# 3              MLR_4              basic & categories, not processed
# 6              MLR_7               basic & categories, preprocessed
# 4              MLR_5  basic, individual & categories, not processed
# 5              MLR_6               basic & individual, preprocessed
#
#     Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                   1562209.347000              0.662000
# 1                   1562208.121000              0.662000
# 8                   1562208.548000              0.662000
# 9                   1562207.421000              0.662000
# 10                  1562294.896000              0.662000
# 7                   1567862.487000              0.660000
# 2                   1573193.418000              0.657000
# 3                   1575590.586000              0.658000
# 6                   1575590.586000              0.658000
# 4                   1580000.765000              0.654000
# 5                   1580000.765000              0.654000
#
#     Adjusted R-squared (training)  R-squared (test)  \
# 0                        0.661000          0.660000
# 1                        0.661000          0.660000
# 8                        0.661000          0.660000
# 9                        0.661000          0.660000
# 10                       0.661000          0.660000
# 7                        0.659000          0.658000
# 2                        0.657000          0.656000
# 3                        0.657000          0.654000
# 6                        0.657000          0.654000
# 4                        0.654000          0.653000
# 5                        0.654000          0.653000
#
#     Adjusted R-squared (test)  5-Fold Cross Validation
# 0                    0.656000                 0.659000
# 1                    0.656000                 0.659000
# 8                    0.656000                 0.659000
# 9                    0.656000                 0.659000
# 10                   0.656000                 0.659000
# 7                    0.656000                 0.658000
# 2                    0.654000                 0.656000
# 3                    0.653000                 0.656000
# 6                    0.653000                 0.656000
# 4                    0.652000                 0.653000
# 5                    0.652000                 0.653000

# %% [markdown]
# # Ridge Regression: Basic and Individual, Not Processed

# %%
features = ['age', 'overall_rating', 'potential', 'preferred_foot', 'short_passing', 'long_passing', 'ball_control', 'reactions', 'shot_power', 'vision', 'composure']

# %%
complex_model_R = linear_model.Ridge(alpha=1)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred1 = complex_model_R.predict(test_data[features])
rmsecm1 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred1)),'.3f'))
rtrcm1 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm1 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm1 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm1 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv1 = float(format(cross_val_score(linear_model.Ridge(alpha=1),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=100)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred2 = complex_model_R.predict(test_data[features])
rmsecm2 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred2)),'.3f'))
rtrcm2 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm2 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm2 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm2 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv2 = float(format(cross_val_score(linear_model.Ridge(alpha=100),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=1000)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred3 = complex_model_R.predict(test_data[features])
rmsecm3 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred3)),'.3f'))
rtrcm3 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm3 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm3 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm3 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv3 = float(format(cross_val_score(linear_model.Ridge(alpha=1000),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['Ridge Regression','alpha=1, basic and individual, not processed',rmsecm1,rtrcm1,artrcm1,rtecm1,artecm1,cv1]
evaluate.loc[r+1] = ['Ridge Regression','alpha=100, basic and individual, not processed',rmsecm2,rtrcm2,artrcm2,rtecm2,artecm2,cv2]
evaluate.loc[r+2] = ['Ridge Regression','alpha=1000, basic and individual, not processed',rmsecm3,rtrcm3,artrcm3,rtecm3,artecm3,cv3]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False)
# Out:
#                Model                                          Details  \
# 0              MLR_1                      all features, not processed
# 1              MLR_2                       all features, preprocessed
# 8   Ridge Regression             alpha=1, all features, not processed
# 9   Ridge Regression           alpha=100, all features, not processed
# 10  Ridge Regression          alpha=1000, all features, not processed
# 7              MLR_8     basic, individual & categories, preprocessed
# 2              MLR_3                basic & individual, not processed
# 3              MLR_4                basic & categories, not processed
# 6              MLR_7                 basic & categories, preprocessed
# 11  Ridge Regression     alpha=1, basic and individual, not processed
# 12  Ridge Regression   alpha=100, basic and individual, not processed
# 13  Ridge Regression  alpha=1000, basic and individual, not processed
# 4              MLR_5    basic, individual & categories, not processed
# 5              MLR_6                 basic & individual, preprocessed
#
#     Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                   1562209.347000              0.662000
# 1                   1562208.121000              0.662000
# 8                   1562208.548000              0.662000
# 9                   1562207.421000              0.662000
# 10                  1562294.896000              0.662000
# 7                   1567862.487000              0.660000
# 2                   1573193.418000              0.657000
# 3                   1575590.586000              0.658000
# 6                   1575590.586000              0.658000
# 11                  1573193.421000              0.657000
# 12                  1573194.848000              0.657000
# 13                  1573272.934000              0.657000
# 4                   1580000.765000              0.654000
# 5                   1580000.765000              0.654000
#
#     Adjusted R-squared (training)  R-squared (test)  \
# 0                        0.661000          0.660000
# 1                        0.661000          0.660000
# 8                        0.661000          0.660000
# 9                        0.661000          0.660000
# 10                       0.661000          0.660000
# 7                        0.659000          0.658000
# 2                        0.657000          0.656000
# 3                        0.657000          0.654000
# 6                        0.657000          0.654000
# 11                       0.657000          0.656000
# 12                       0.657000          0.656000
# 13                       0.657000          0.655000
# 4                        0.654000          0.653000
# 5                        0.654000          0.653000
#
#     Adjusted R-squared (test)  5-Fold Cross Validation
# 0                    0.656000                 0.659000
# 1                    0.656000                 0.659000
# 8                    0.656000                 0.659000
# 9                    0.656000                 0.659000
# 10                   0.656000                 0.659000
# 7                    0.656000                 0.658000
# 2                    0.654000                 0.656000
# 3                    0.653000                 0.656000
# 6                    0.653000                 0.656000
# 11                   0.654000                 0.656000
# 12                   0.654000                 0.656000
# 13                   0.654000                 0.655000
# 4                    0.652000                 0.653000
# 5                    0.652000                 0.653000

# %% [markdown]
# # Ridge Regression: Basic and Categories, Not Processed

# %%
features = ['age','overall_rating','potential','preferred_foot','attacking',
 'skill','movement','power','mentality','defending','goal_keeping']

# %%
complex_model_R = linear_model.Ridge(alpha=1)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred1 = complex_model_R.predict(test_data[features])
rmsecm1 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred1)),'.3f'))
rtrcm1 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm1 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm1 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm1 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv1 = float(format(cross_val_score(linear_model.Ridge(alpha=1),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=100)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred2 = complex_model_R.predict(test_data[features])
rmsecm2 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred2)),'.3f'))
rtrcm2 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm2 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm2 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm2 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv2 = float(format(cross_val_score(linear_model.Ridge(alpha=100),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_R = linear_model.Ridge(alpha=1000)
complex_model_R.fit(train_data[features],train_data['value_euro'])

pred3 = complex_model_R.predict(test_data[features])
rmsecm3 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred3)),'.3f'))
rtrcm3 = float(format(complex_model_R.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm3 = float(format(adjustedR2(complex_model_R.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm3 = float(format(complex_model_R.score(test_data[features],test_data['value_euro']),'.3f'))
artecm3 = float(format(adjustedR2(complex_model_R.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv3 = float(format(cross_val_score(linear_model.Ridge(alpha=1000),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['Ridge Regression','alpha=1, basic & categories, not processed',rmsecm1,rtrcm1,artrcm1,rtecm1,artecm1,cv1]
evaluate.loc[r+1] = ['Ridge Regression','alpha=100, basic & categories, not processed',rmsecm2,rtrcm2,artrcm2,rtecm2,artecm2,cv2]
evaluate.loc[r+2] = ['Ridge Regression','alpha=1000, basic & categories, not processed',rmsecm3,rtrcm3,artrcm3,rtecm3,artecm3,cv3]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False)
# Out:
#                Model                                          Details  \
# 0              MLR_1                      all features, not processed
# 1              MLR_2                       all features, preprocessed
# 10  Ridge Regression          alpha=1000, all features, not processed
# 9   Ridge Regression           alpha=100, all features, not processed
# 8   Ridge Regression             alpha=1, all features, not processed
# 7              MLR_8     basic, individual & categories, preprocessed
# 6              MLR_7                 basic & categories, preprocessed
# 3              MLR_4                basic & categories, not processed
# 2              MLR_3                basic & individual, not processed
# 11  Ridge Regression     alpha=1, basic and individual, not processed
# 12  Ridge Regression   alpha=100, basic and individual, not processed
# 14  Ridge Regression       alpha=1, basic & categories, not processed
# 15  Ridge Regression     alpha=100, basic & categories, not processed
# 16  Ridge Regression    alpha=1000, basic & categories, not processed
# 13  Ridge Regression  alpha=1000, basic and individual, not processed
# 5              MLR_6                 basic & individual, preprocessed
# 4              MLR_5    basic, individual & categories, not processed
#
#     Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                   1562209.347000              0.662000
# 1                   1562208.121000              0.662000
# 10                  1562294.896000              0.662000
# 9                   1562207.421000              0.662000
# 8                   1562208.548000              0.662000
# 7                   1567862.487000              0.660000
# 6                   1575590.586000              0.658000
# 3                   1575590.586000              0.658000
# 2                   1573193.418000              0.657000
# 11                  1573193.421000              0.657000
# 12                  1573194.848000              0.657000
# 14                  1575590.667000              0.658000
# 15                  1575599.611000              0.658000
# 16                  1575742.902000              0.658000
# 13                  1573272.934000              0.657000
# 5                   1580000.765000              0.654000
# 4                   1580000.765000              0.654000
#
#     Adjusted R-squared (training)  R-squared (test)  \
# 0                        0.661000          0.660000
# 1                        0.661000          0.660000
# 10                       0.661000          0.660000
# 9                        0.661000          0.660000
# 8                        0.661000          0.660000
# 7                        0.659000          0.658000
# 6                        0.657000          0.654000
# 3                        0.657000          0.654000
# 2                        0.657000          0.656000
# 11                       0.657000          0.656000
# 12                       0.657000          0.656000
# 14                       0.657000          0.654000
# 15                       0.657000          0.654000
# 16                       0.657000          0.654000
# 13                       0.657000          0.655000
# 5                        0.654000          0.653000
# 4                        0.654000          0.653000
#
#     Adjusted R-squared (test)  5-Fold Cross Validation
# 0                    0.656000                 0.659000
# 1                    0.656000                 0.659000
# 10                   0.656000                 0.659000
# 9                    0.656000                 0.659000
# 8                    0.656000                 0.659000
# 7                    0.656000                 0.658000
# 6                    0.653000                 0.656000
# 3                    0.653000                 0.656000
# 2                    0.654000                 0.656000
# 11                   0.654000                 0.656000
# 12                   0.654000                 0.656000
# 14                   0.653000                 0.656000
# 15                   0.653000                 0.656000
# 16                   0.653000                 0.656000
# 13                   0.654000                 0.655000
# 5                    0.652000                 0.653000
# 4                    0.652000                 0.653000

# %% [markdown]
# # <span id="16"></span> Lasso: All Features, Not Processed
# #### [Return Contents](#0)

# %%
features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']

# %%
complex_model_L = linear_model.Lasso(alpha=1)
complex_model_L.fit(train_data[features],train_data['value_euro'])

pred1 = complex_model_L.predict(test_data[features])
rmsecm1 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred1)),'.3f'))
rtrcm1 = float(format(complex_model_L.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm1 = float(format(adjustedR2(complex_model_L.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm1 = float(format(complex_model_L.score(test_data[features],test_data['value_euro']),'.3f'))
artecm1 = float(format(adjustedR2(complex_model_L.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv1 = float(format(cross_val_score(linear_model.Lasso(alpha=1),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_L = linear_model.Lasso(alpha=100)
complex_model_L.fit(train_data[features],train_data['value_euro'])

pred2 = complex_model_L.predict(test_data[features])
rmsecm2 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred2)),'.3f'))
rtrcm2 = float(format(complex_model_L.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm2 = float(format(adjustedR2(complex_model_L.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm2 = float(format(complex_model_L.score(test_data[features],test_data['value_euro']),'.3f'))
artecm2 = float(format(adjustedR2(complex_model_L.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv2 = float(format(cross_val_score(linear_model.Lasso(alpha=100),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

complex_model_L = linear_model.Lasso(alpha=1000)
complex_model_L.fit(train_data[features],train_data['value_euro'])

pred3 = complex_model_L.predict(test_data[features])
rmsecm3 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred3)),'.3f'))
rtrcm3 = float(format(complex_model_L.score(train_data[features],train_data['value_euro']),'.3f'))
artrcm3 = float(format(adjustedR2(complex_model_L.score(train_data[features],train_data['value_euro']),train_data.shape[0],len(features)),'.3f'))
rtecm3 = float(format(complex_model_L.score(test_data[features],test_data['value_euro']),'.3f'))
artecm3 = float(format(adjustedR2(complex_model_L.score(test_data[features],test_data['value_euro']),test_data.shape[0],len(features)),'.3f'))
cv3 = float(format(cross_val_score(linear_model.Lasso(alpha=1000),train_data[features],train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate.shape[0]
evaluate.loc[r] = ['Lasso Regression','alpha=1, all features',rmsecm1,rtrcm1,artrcm1,rtecm1,artecm1,cv1]
evaluate.loc[r+1] = ['Lasso Regression','alpha=100, all features',rmsecm2,rtrcm2,artrcm2,rtecm2,artecm2,cv2]
evaluate.loc[r+2] = ['Lasso Regression','alpha=1000, all features',rmsecm3,rtrcm3,artrcm3,rtecm3,artecm3,cv3]
evaluate.sort_values(by = '5-Fold Cross Validation', ascending=False)
# Out:
#                Model                                          Details  \
# 0              MLR_1                      all features, not processed
# 8   Ridge Regression             alpha=1, all features, not processed
# 18  Lasso Regression                          alpha=100, all features
# 17  Lasso Regression                            alpha=1, all features
# 1              MLR_2                       all features, preprocessed
# 9   Ridge Regression           alpha=100, all features, not processed
# 10  Ridge Regression          alpha=1000, all features, not processed
# 19  Lasso Regression                         alpha=1000, all features
# 7              MLR_8     basic, individual & categories, preprocessed
# 6              MLR_7                 basic & categories, preprocessed
# 11  Ridge Regression     alpha=1, basic and individual, not processed
# 12  Ridge Regression   alpha=100, basic and individual, not processed
# 14  Ridge Regression       alpha=1, basic & categories, not processed
# 15  Ridge Regression     alpha=100, basic & categories, not processed
# 16  Ridge Regression    alpha=1000, basic & categories, not processed
# 3              MLR_4                basic & categories, not processed
# 2              MLR_3                basic & individual, not processed
# 13  Ridge Regression  alpha=1000, basic and individual, not processed
# 5              MLR_6                 basic & individual, preprocessed
# 4              MLR_5    basic, individual & categories, not processed
#
#     Root Mean Squared Error (RMSE)  R-squared (training)  \
# 0                   1562209.347000              0.662000
# 8                   1562208.548000              0.662000
# 18                  1562209.716000              0.662000
# 17                  1562208.585000              0.662000
# 1                   1562208.121000              0.662000
# 9                   1562207.421000              0.662000
# 10                  1562294.896000              0.662000
# 19                  1562239.375000              0.662000
# 7                   1567862.487000              0.660000
# 6                   1575590.586000              0.658000
# 11                  1573193.421000              0.657000
# 12                  1573194.848000              0.657000
# 14                  1575590.667000              0.658000
# 15                  1575599.611000              0.658000
# 16                  1575742.902000              0.658000
# 3                   1575590.586000              0.658000
# 2                   1573193.418000              0.657000
# 13                  1573272.934000              0.657000
# 5                   1580000.765000              0.654000
# 4                   1580000.765000              0.654000
#
#     Adjusted R-squared (training)  R-squared (test)  \
# 0                        0.661000          0.660000
# 8                        0.661000          0.660000
# 18                       0.661000          0.660000
# 17                       0.661000          0.660000
# 1                        0.661000          0.660000
# 9                        0.661000          0.660000
# 10                       0.661000          0.660000
# 19                       0.661000          0.660000
# 7                        0.659000          0.658000
# 6                        0.657000          0.654000
# 11                       0.657000          0.656000
# 12                       0.657000          0.656000
# 14                       0.657000          0.654000
# 15                       0.657000          0.654000
# 16                       0.657000          0.654000
# 3                        0.657000          0.654000
# 2                        0.657000          0.656000
# 13                       0.657000          0.655000
# 5                        0.654000          0.653000
# 4                        0.654000          0.653000
#
#     Adjusted R-squared (test)  5-Fold Cross Validation
# 0                    0.656000                 0.659000
# 8                    0.656000                 0.659000
# 18                   0.656000                 0.659000
# 17                   0.656000                 0.659000
# 1                    0.656000                 0.659000
# 9                    0.656000                 0.659000
# 10                   0.656000                 0.659000
# 19                   0.656000                 0.659000
# 7                    0.656000                 0.658000
# 6                    0.653000                 0.656000
# 11                   0.654000                 0.656000
# 12                   0.654000                 0.656000
# 14                   0.653000                 0.656000
# 15                   0.653000                 0.656000
# 16                   0.653000                 0.656000
# 3                    0.653000                 0.656000
# 2                    0.654000                 0.656000
# 13                   0.654000                 0.655000
# 5                    0.652000                 0.653000
# 4                    0.652000                 0.653000

# %% [markdown]
# # Polynomial  Regression

# %%
evaluate_poly = pd.DataFrame({'Model': [],
                                'Details':[],
                                'Root Mean Squared Error (RMSE)':[],
                                'R-squared (training)':[],
                                'Adjusted R-squared (training)':[],
                                'R-squared (test)':[],
                                'Adjusted R-squared (test)':[],
                                '5-Fold Cross Validation':[]})

#basic & categories not prcoess
features =['age','overall_rating','potential','preferred_foot','attacking',
 'skill','movement','power','mentality','defending','goal_keeping',]

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.LinearRegression().fit(X_trainpoly, train_data['value_euro'])

pred1 = poly.predict(X_testpoly)
rmsepoly1 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred1)),'.3f'))
rtrpoly1 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly1 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv1 = float(format(cross_val_score(linear_model.LinearRegression(),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=3)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.LinearRegression().fit(X_trainpoly, train_data['value_euro'])

pred2 = poly.predict(X_testpoly)
rmsepoly2 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred2)),'.3f'))
rtrpoly2 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly2 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv2 = float(format(cross_val_score(linear_model.LinearRegression(),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

#all features not processed 
features = features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']
polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.LinearRegression().fit(X_trainpoly, train_data['value_euro'])

pred3 = poly.predict(X_testpoly)
rmsepoly3 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred3)),'.3f'))
rtrpoly3 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly3 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv3 = float(format(cross_val_score(linear_model.LinearRegression(),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=3)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.LinearRegression().fit(X_trainpoly, train_data['value_euro'])

pred4 = poly.predict(X_testpoly)
rmsepoly4 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred4)),'.3f'))
rtrpoly4 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly4 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv4 = float(format(cross_val_score(linear_model.LinearRegression(),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

# all features processed 
features = ['age_scaled', 'height_cm_scaled', 'weight_kgs_scaled', 'overall_rating_scaled', 'potential_scaled', 'preferred_foot_scaled', 'crossing_scaled', 'finishing_scaled', 'heading_accuracy_scaled',
       'short_passing_scaled', 'volleys_scaled', 'dribbling_scaled', 'curve_scaled', 'freekick_accuracy_scaled',
       'long_passing_scaled', 'ball_control_scaled', 'acceleration_scaled', 'sprint_speed_scaled',
       'agility_scaled', 'reactions_scaled', 'balance_scaled', 'shot_power_scaled', 'jumping_scaled', 'stamina_scaled',
       'strength_scaled', 'long_shots_scaled', 'aggression_scaled', 'interceptions_scaled', 'positioning_scaled',
       'vision_scaled', 'penalties_scaled', 'composure_scaled', 'marking_scaled_scaled', 'standing_tackle_scaled',
       'sliding_tackle_scaled', 'GK_diving_scaled', 'GK_handling_scaled', 'GK_kicking_scaled',
       'GK_positioning_scaled', 'GK_reflexes_scaled', 'attacking_scaled', 'skill_scaled', 'movement_scaled',
       'power_scaled', 'mentality_scaled', 'defending_scaled', 'goal_keeping_scaled']

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.LinearRegression().fit(X_trainpoly, train_data['value_euro'])

pred5 = poly.predict(X_testpoly)
rmsepoly5 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred5)),'.3f'))
rtrpoly5 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly5 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv5 = float(format(cross_val_score(linear_model.LinearRegression(),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.Ridge(alpha=1).fit(X_trainpoly, train_data['value_euro'])

pred6 = poly.predict(X_testpoly)
rmsepoly6 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred6)),'.3f'))
rtrpoly6 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly6 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv6 = float(format(cross_val_score(linear_model.Ridge(alpha=1),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.Ridge(alpha=50000).fit(X_trainpoly, train_data['value_euro'])

pred7 = poly.predict(X_testpoly)
rmsepoly7 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred7)),'.3f'))
rtrpoly7 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly7 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv7 = float(format(cross_val_score(linear_model.Ridge(alpha=50000),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.Lasso(alpha=1).fit(X_trainpoly, train_data['value_euro'])

pred8 = poly.predict(X_testpoly)
rmsepoly8 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred8)),'.3f'))
rtrpoly8 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly8 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv8 = float(format(cross_val_score(linear_model.Lasso(alpha=1),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

polyfeat = PolynomialFeatures(degree=2)
X_allpoly = polyfeat.fit_transform(df[features])
X_trainpoly = polyfeat.fit_transform(train_data[features])
X_testpoly = polyfeat.fit_transform(test_data[features])
poly = linear_model.Lasso(alpha=50000).fit(X_trainpoly, train_data['value_euro'])

pred9 = poly.predict(X_testpoly)
rmsepoly9 = float(format(np.sqrt(metrics.mean_squared_error(test_data['value_euro'],pred9)),'.3f'))
rtrpoly9 = float(format(poly.score(X_trainpoly,train_data['value_euro']),'.3f'))
rtepoly9 = float(format(poly.score(X_testpoly,test_data['value_euro']),'.3f'))
cv9 = float(format(cross_val_score(linear_model.Lasso(alpha=50000),X_trainpoly,train_data['value_euro'],cv=5).mean(),'.3f'))

r = evaluate_poly.shape[0]
evaluate_poly.loc[r] = ['Polynomial Regression','degree=2, basic&categories, no preprocessing',rmsepoly1,rtrpoly1,'-',rtepoly1,'-',cv1]
evaluate_poly.loc[r+1] = ['Polynomial Regression','degree=3, basic&categories, no preprocessing',rmsepoly2,rtrpoly2,'-',rtepoly2,'-',cv2]
evaluate_poly.loc[r+2] = ['Polynomial Regression','degree=2, all features, no preprocessing',rmsepoly3,rtrpoly3,'-',rtepoly3,'-',cv3]
evaluate_poly.loc[r+3] = ['Polynomial Regression','degree=3, all features, no preprocessing',rmsepoly4,rtrpoly4,'-',rtepoly4,'-',cv4]
evaluate_poly.loc[r+4] = ['Polynomial Regression','degree=2, all features',rmsepoly5,rtrpoly5,'-',rtepoly5,'-',cv5]
evaluate_poly.loc[r+5] = ['Polynomial Ridge Regression','alpha=1, degree=2, all features',rmsepoly6,rtrpoly6,'-',rtepoly6,'-',cv6]
evaluat_poly.loc[r+6] = ['Polynomial Ridge Regression','alpha=50000, degree=2, all features',rmsepoly7,rtrpoly7,'-',rtepoly7,'-',cv7]
evaluate_poly.loc[r+7] = ['Polynomial Lasso Regression','alpha=1, degree=2, all features',rmsepoly8,rtrpoly8,'-',rtepoly8,'-',cv8]
evaluate_poly.loc[r+8] = ['Polynomial Lasso Regression','alpha=50000, degree=2, all features',rmsepoly9,rtrpoly9,'-',rtepoly9,'-',cv9]
evaluate_poly_temp = evaluation_poly[['Model','Details','Root Mean Squared Error (RMSE)','R-squared (training)','R-squared (test)','5-Fold Cross Validation']]
evaluate_poly_temp.sort_values(by = '5-Fold Cross Validation', ascending=False)

# %% [markdown]
# # <span id="17"></span> Normality & Homoscedasticity
# #### [Return Contents](#0)

# %% [markdown]
# We graphed the residuals to see how normally distributed they are and if we were encountering heteroscedasticity which would interfer with our model's effectiveness.

# %% [markdown]
# ### MLR_1: All Features, No Processing

# %%
features = ['age', 'height_cm', 'weight_kgs', 'overall_rating', 'potential', 'preferred_foot', 'crossing', 'finishing', 'heading_accuracy',
       'short_passing', 'volleys', 'dribbling', 'curve', 'freekick_accuracy',
       'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
       'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
       'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
       'vision', 'penalties', 'composure', 'marking', 'standing_tackle',
       'sliding_tackle', 'GK_diving', 'GK_handling', 'GK_kicking',
       'GK_positioning', 'GK_reflexes', 'attacking', 'skill', 'movement',
       'power', 'mentality', 'defending', 'goal_keeping']

# %%
complex_model_2 = linear_model.LinearRegression()
complex_model_2.fit(train_data[features],train_data['value_euro'])

print('Intercept: {}'.format(complex_model_2.intercept_))
print('Coefficients: {}'.format(complex_model_2.coef_))
# Out:
# Intercept: -19944183.636227656
# Coefficients: [-1.97110546e+05  1.64677630e+03  8.50014835e+03  3.80656155e+05
#   1.06909279e+04  9.98114389e+04 -1.38268645e+15 -1.38268645e+15
#  -1.38268645e+15 -1.38268645e+15 -1.38268645e+15  4.36413049e+14
#   4.36413049e+14  4.36413049e+14  4.36413049e+14  4.36413049e+14
#   1.37142420e+15  1.37142420e+15  1.37142420e+15  1.37142420e+15
#   1.37142420e+15  7.81033062e+14  7.81033062e+14  7.81033062e+14
#   7.81033062e+14  7.81033062e+14 -7.35118644e+14 -7.35118644e+14
#  -7.35118644e+14 -7.35118644e+14 -7.35118644e+14 -7.35118644e+14
#  -5.43877521e+15 -5.43877521e+15 -5.43877521e+15  4.48537817e+14
#   4.48537817e+14  4.48537817e+14  4.48537817e+14  4.48537817e+14
#   6.91343226e+15 -2.18206524e+15 -6.85712098e+15 -3.90516531e+15
#   4.41071186e+15  1.63163256e+16 -2.24268908e+15]

# %%
y_pred = complex_model_2.predict(test_data[features])

# %%
## The line / model
plt.scatter(y_pred, test_data['value_euro'])
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.savefig('graph9.png',dpi=100,bbox_inches = 'tight')

# %%
sns.residplot(y_pred, test_data['value_euro'], lowess=True, color="g")

# %%
from sklearn import metrics

# %%
y_pred_train = complex_model_2.predict(train_data[features])

# %%
train_mae = metrics.mean_absolute_error(train_data['value_euro'], y_pred_train)
train_mse = metrics.mean_squared_error(train_data['value_euro'], y_pred_train)
train_rmse = np.sqrt(metrics.mean_squared_error(train_data['value_euro'], y_pred_train))
print('Mean Absolute Error:', train_mae )
print('Mean Squared Error:',  train_mse)
print('Root Mean Squared Error:' , train_rmse)
# Out:
# Mean Absolute Error: 1160448.1923464395
# Mean Squared Error: 2394482369774.1177
# Root Mean Squared Error: 1547411.5062820613

# %%
test_mae = metrics.mean_absolute_error(test_data['value_euro'], y_pred)
test_mse = metrics.mean_squared_error(test_data['value_euro'], y_pred)
test_rmse = np.sqrt(metrics.mean_squared_error(test_data['value_euro'], y_pred))
print('Mean Absolute Error:' + str(metrics.mean_absolute_error(test_data['value_euro'], y_pred)))
print('Mean Squared Error:' + str(metrics.mean_squared_error(test_data['value_euro'], y_pred)))
print('Root Mean Squared Error:' + str(np.sqrt(metrics.mean_squared_error(test_data['value_euro'], y_pred))))
# Out:
# Mean Absolute Error:1170178.7807387938
# Mean Squared Error:2440498042728.6133
# Root Mean Squared Error:1562209.3466397559
